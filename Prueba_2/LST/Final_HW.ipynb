# %%
import numpy as np
import matplotlib.pyplot as plt
import gmsh
import os
import meshio
import math
import sys
from matplotlib.patches import Polygon

from LST import LST
from Node import Node
from units import mm, cm, m, kgf, N, tf, kN, MPa, GPa
from fem import Material, Membrane
from functions import matrix_extract,  get_nodes_from_physical_id, get_line_load_global_vector, matrix_replace

# %%
output_file= "mallas/malla_LST.msh"

# %%
ASTM_36 = Material.Material(name="ASTM 36", E=200.0 * GPa, nu=0.30, rho=7850 * kgf / (m**3))
Sup1 = Membrane.Membrane(name="Steel", thickness=2 * cm, material=ASTM_36)
Sup2 = Membrane.Membrane(name="Steel", thickness=2 * cm, material=ASTM_36)
section_dict = {"Steel1": Sup1, "Steel2":Sup2}

# %%
mesh = meshio.read(output_file)

# Asociación de tag físico con nombre
tag_to_name = {v[0]: k for k, v in mesh.field_data.items()}

# Diccionario {nombre_grupo: [Node, Node, ...]}
grupos = {}
Materials = {}
# Procesar elementos tipo triangle
for cell_block, phys_tags in zip(mesh.cells, mesh.cell_data["gmsh:physical"]):
    if cell_block.type != "triangle6":
        continue
    for tri, tag in zip(cell_block.data, phys_tags):
        nombre = tag_to_name.get(tag, f"{tag}")

        if nombre not in grupos:
            grupos[nombre] = []
        for node_id in tri:
            x, y = mesh.points[node_id][:2]
            grupos[nombre].append(Node(node_id+1, (x, y)))


# Procesar elementos tipo line (para grupos como "Fuerza")
for cell_block, phys_tags in zip(mesh.cells, mesh.cell_data["gmsh:physical"]):
    if cell_block.type != "line3":
        continue
    for line, tag in zip(cell_block.data, phys_tags):
        nombre = tag_to_name.get(tag, f"{tag}")
        if nombre not in grupos:
            grupos[nombre] = []
        for node_id in line:
            x, y = mesh.points[node_id][:2]
            restrain = ["f", "f"]
            if nombre in ["BC_R1"]:
                restrain = ["r", "r"]
            grupos[nombre].append(Node(node_id+1, (x, y), restrain=restrain))
# Eliminar nodos duplicados por grupo
for nombre in grupos:
    nodos_unicos = {}
    for n in grupos[nombre]:
        nodos_unicos[n.name] = n
    grupos[nombre] = list(nodos_unicos.values())
    print(f"Grupo {nombre} - Cantidad de nodos: {len(grupos[nombre])}")
nodes_dict = {}
for group in grupos:
    for node in grupos[group]:
        nodes_dict[node.name] = node
# Out:
# Grupo Steel1 - Cantidad de nodos: 703
# Grupo Steel2 - Cantidad de nodos: 703
# Grupo BC_1 - Cantidad de nodos: 37
# Grupo BC_R1 - Cantidad de nodos: 19

# %%
# Procesando los elementos de tipo "triangle6" (con 6 nodos)
triangles = mesh.cells_dict['triangle6']  # Obtiene los elementos de tipo 'triangle6'
tags = mesh.cell_data_dict["gmsh:physical"]["triangle6"]  # Obtiene las etiquetas de los elementos
elements = []  # Lista para almacenar los elementos procesados
nodes = set()  # Conjunto para almacenar los nodos únicos
print(f"Cantidad de triángulos: {len(tags)}")

# Recorremos los triángulos
for i in range(len(tags)):
    tag = tags[i]
    group_name = tag_to_name.get(tag, f"{tag}")  # Obtener el nombre del grupo

    # Verificar si el material está en section_dict
    if group_name not in section_dict:
        print(f"Advertencia: El material '{group_name}' no se encuentra en section_dict.")
        continue  # O usar un valor por defecto si es necesario

    material = section_dict[group_name]  # Obtener el material correspondiente

    node_ids = triangles[i]  # Obtener los IDs de los nodos para este elemento
    
    # Verificar que los nodos sean válidos
    print(f"Recuperando nodos para el triángulo {i+1} con ids: {node_ids}")
    
    # Comprobamos si los nodos existen en el diccionario
    try:
        nodo_a = nodes_dict.get(node_ids[0]+1)
        nodo_b = nodes_dict.get(node_ids[1]+1)
        nodo_c = nodes_dict.get(node_ids[2]+1)
        nodo_d = nodes_dict.get(node_ids[3]+1)
        nodo_e = nodes_dict.get(node_ids[4]+1)
        nodo_f = nodes_dict.get(node_ids[5]+1)
    except KeyError as e:
        print(f"Error recuperando nodos: {e}")
        continue  # Saltar al siguiente triángulo si hay un problema con los nodos

    # Si todos los nodos son válidos, procedemos
    for nodo in [nodo_a, nodo_b, nodo_c, nodo_d, nodo_e, nodo_f]:
        nodes.add(nodo)

    # Crear la lista de nodos (usando todos los nodos del triángulo)
    elem = [nodo_a, nodo_b, nodo_c, nodo_d, nodo_e, nodo_f]
    print(f"Triángulo {i+1} - Nodos: {[n.name for n in elem]} - Material: {material.name}")

    # Si los nodos fueron reordenados correctamente, crear el objeto LST
    if elem:
        element = LST(i + 1, elem, section=material)
        print(f"Elemento {element.element_tag} - Nodos: {[n.name for n in element.nodes]} - Material: {element.section.name}")
        elements.append(element)
        print(f"Elemento {i+1} procesado correctamente.")

# Convertir el conjunto de nodos a una lista
nodes = list(nodes)
# Out:
# Cantidad de triángulos: 648
# Recuperando nodos para el triángulo 1 con ids: [  0   9 162  17 277 170]
# Triángulo 1 - Nodos: [np.int32(1), np.int32(10), np.int32(163), np.int32(18), np.int32(278), np.int32(171)] - Material: Steel
# Elemento 1 - Nodos: [np.int32(1), np.int32(10), np.int32(163), np.int32(18), np.int32(278), np.int32(171)] - Material: Steel
# Elemento 1 procesado correctamente.
# Recuperando nodos para el triángulo 2 con ids: [162   9 213 277 278 279]
# Triángulo 2 - Nodos: [np.int32(163), np.int32(10), np.int32(214), np.int32(278), np.int32(279), np.int32(280)] - Material: Steel
# Elemento 2 - Nodos: [np.int32(163), np.int32(10), np.int32(214), np.int32(278), np.int32(279), np.int32(280)] - Material: Steel
# Elemento 2 procesado correctamente.
# Recuperando nodos para el triángulo 3 con ids: [162 213 163 279 280 171]
# Triángulo 3 - Nodos: [np.int32(163), np.int32(214), np.int32(164), np.int32(280), np.int32(281), np.int32(172)] - Material: Steel
# Elemento 3 - Nodos: [np.int32(163), np.int32(214), np.int32(164), np.int32(280), np.int32(281), np.int32(172)] - Material: Steel
# Elemento 3 procesado correctamente.
# Recuperando nodos para el triángulo 4 con ids: [163 213 214 280 281 282]
# Triángulo 4 - Nodos: [np.int32(164), np.int32(214), np.int32(215), np.int32(281), np.int32(282), np.int32(283)] - Material: Steel
# Elemento 4 - Nodos: [np.int32(164), np.int32(214), np.int32(215), np.int32(281), np.int32(282), np.int32(283)] - Material: Steel
# Elemento 4 procesado correctamente.
# Recuperando nodos para el triángulo 5 con ids: [163 214 164 282 283 172]
# Triángulo 5 - Nodos: [np.int32(164), np.int32(215), np.int32(165), np.int32(283), np.int32(284), np.int32(173)] - Material: Steel
# Elemento 5 - Nodos: [np.int32(164), np.int32(215), np.int32(165), np.int32(283), np.int32(284), np.int32(173)] - Material: Steel
# Elemento 5 procesado correctamente.
# Recuperando nodos para el triángulo 6 con ids: [164 214 215 283 284 285]
# Triángulo 6 - Nodos: [np.int32(165), np.int32(215), np.int32(216), np.int32(284), np.int32(285), np.int32(286)] - Material: Steel
# Elemento 6 - Nodos: [np.int32(165), np.int32(215), np.int32(216), np.int32(284), np.int32(285), np.int32(286)] - Material: Steel
# Elemento 6 procesado correctamente.
# Recuperando nodos para el triángulo 7 con ids: [164 215 165 285 286 173]
# Triángulo 7 - Nodos: [np.int32(165), np.int32(216), np.int32(166), np.int32(286), np.int32(287), np.int32(174)] - Material: Steel
# Elemento 7 - Nodos: [np.int32(165), np.int32(216), np.int32(166), np.int32(286), np.int32(287), np.int32(174)] - Material: Steel
# Elemento 7 procesado correctamente.
# Recuperando nodos para el triángulo 8 con ids: [165 215 216 286 287 288]
# Triángulo 8 - Nodos: [np.int32(166), np.int32(216), np.int32(217), np.int32(287), np.int32(288), np.int32(289)] - Material: Steel
# Elemento 8 - Nodos: [np.int32(166), np.int32(216), np.int32(217), np.int32(287), np.int32(288), np.int32(289)] - Material: Steel
# Elemento 8 procesado correctamente.
# Recuperando nodos para el triángulo 9 con ids: [165 216 166 288 289 174]
# Triángulo 9 - Nodos: [np.int32(166), np.int32(217), np.int32(167), np.int32(289), np.int32(290), np.int32(175)] - Material: Steel
# Elemento 9 - Nodos: [np.int32(166), np.int32(217), np.int32(167), np.int32(289), np.int32(290), np.int32(175)] - Material: Steel
# Elemento 9 procesado correctamente.
# Recuperando nodos para el triángulo 10 con ids: [166 216 217 289 290 291]
# Triángulo 10 - Nodos: [np.int32(167), np.int32(217), np.int32(218), np.int32(290), np.int32(291), np.int32(292)] - Material: Steel
# Elemento 10 - Nodos: [np.int32(167), np.int32(217), np.int32(218), np.int32(290), np.int32(291), np.int32(292)] - Material: Steel
# Elemento 10 procesado correctamente.
# Recuperando nodos para el triángulo 11 con ids: [166 217 167 291 292 175]
# Triángulo 11 - Nodos: [np.int32(167), np.int32(218), np.int32(168), np.int32(292), np.int32(293), np.int32(176)] - Material: Steel
# Elemento 11 - Nodos: [np.int32(167), np.int32(218), np.int32(168), np.int32(292), np.int32(293), np.int32(176)] - Material: Steel
# Elemento 11 procesado correctamente.
# Recuperando nodos para el triángulo 12 con ids: [167 217 218 292 293 294]
# Triángulo 12 - Nodos: [np.int32(168), np.int32(218), np.int32(219), np.int32(293), np.int32(294), np.int32(295)] - Material: Steel
# Elemento 12 - Nodos: [np.int32(168), np.int32(218), np.int32(219), np.int32(293), np.int32(294), np.int32(295)] - Material: Steel
# Elemento 12 procesado correctamente.
# Recuperando nodos para el triángulo 13 con ids: [167 218 168 294 295 176]
# Triángulo 13 - Nodos: [np.int32(168), np.int32(219), np.int32(169), np.int32(295), np.int32(296), np.int32(177)] - Material: Steel
# Elemento 13 - Nodos: [np.int32(168), np.int32(219), np.int32(169), np.int32(295), np.int32(296), np.int32(177)] - Material: Steel
# Elemento 13 procesado correctamente.
# Recuperando nodos para el triángulo 14 con ids: [168 218 219 295 296 297]
# Triángulo 14 - Nodos: [np.int32(169), np.int32(219), np.int32(220), np.int32(296), np.int32(297), np.int32(298)] - Material: Steel
# Elemento 14 - Nodos: [np.int32(169), np.int32(219), np.int32(220), np.int32(296), np.int32(297), np.int32(298)] - Material: Steel
# Elemento 14 procesado correctamente.
# Recuperando nodos para el triángulo 15 con ids: [168 219 169 297 298 177]
# Triángulo 15 - Nodos: [np.int32(169), np.int32(220), np.int32(170), np.int32(298), np.int32(299), np.int32(178)] - Material: Steel
# Elemento 15 - Nodos: [np.int32(169), np.int32(220), np.int32(170), np.int32(298), np.int32(299), np.int32(178)] - Material: Steel
# Elemento 15 procesado correctamente.
# Recuperando nodos para el triángulo 16 con ids: [169 219 220 298 299 300]
# Triángulo 16 - Nodos: [np.int32(170), np.int32(220), np.int32(221), np.int32(299), np.int32(300), np.int32(301)] - Material: Steel
# Elemento 16 - Nodos: [np.int32(170), np.int32(220), np.int32(221), np.int32(299), np.int32(300), np.int32(301)] - Material: Steel
# Elemento 16 procesado correctamente.
# Recuperando nodos para el triángulo 17 con ids: [169 220   8 300 301 178]
# Triángulo 17 - Nodos: [np.int32(170), np.int32(221), np.int32(9), np.int32(301), np.int32(302), np.int32(179)] - Material: Steel
# Elemento 17 - Nodos: [np.int32(170), np.int32(221), np.int32(9), np.int32(301), np.int32(302), np.int32(179)] - Material: Steel
# Elemento 17 procesado correctamente.
# Recuperando nodos para el triángulo 18 con ids: [  8 220 145 301 302 153]
# Triángulo 18 - Nodos: [np.int32(9), np.int32(221), np.int32(146), np.int32(302), np.int32(303), np.int32(154)] - Material: Steel
# Elemento 18 - Nodos: [np.int32(9), np.int32(221), np.int32(146), np.int32(302), np.int32(303), np.int32(154)] - Material: Steel
# Elemento 18 procesado correctamente.
# Recuperando nodos para el triángulo 19 con ids: [  9  10 213  18 303 278]
# Triángulo 19 - Nodos: [np.int32(10), np.int32(11), np.int32(214), np.int32(19), np.int32(304), np.int32(279)] - Material: Steel
# Elemento 19 - Nodos: [np.int32(10), np.int32(11), np.int32(214), np.int32(19), np.int32(304), np.int32(279)] - Material: Steel
# Elemento 19 procesado correctamente.
# Recuperando nodos para el triángulo 20 con ids: [213  10 221 303 304 305]
# Triángulo 20 - Nodos: [np.int32(214), np.int32(11), np.int32(222), np.int32(304), np.int32(305), np.int32(306)] - Material: Steel
# Elemento 20 - Nodos: [np.int32(214), np.int32(11), np.int32(222), np.int32(304), np.int32(305), np.int32(306)] - Material: Steel
# Elemento 20 procesado correctamente.
# Recuperando nodos para el triángulo 21 con ids: [213 221 214 305 306 281]
# Triángulo 21 - Nodos: [np.int32(214), np.int32(222), np.int32(215), np.int32(306), np.int32(307), np.int32(282)] - Material: Steel
# Elemento 21 - Nodos: [np.int32(214), np.int32(222), np.int32(215), np.int32(306), np.int32(307), np.int32(282)] - Material: Steel
# Elemento 21 procesado correctamente.
# Recuperando nodos para el triángulo 22 con ids: [214 221 222 306 307 308]
# Triángulo 22 - Nodos: [np.int32(215), np.int32(222), np.int32(223), np.int32(307), np.int32(308), np.int32(309)] - Material: Steel
# Elemento 22 - Nodos: [np.int32(215), np.int32(222), np.int32(223), np.int32(307), np.int32(308), np.int32(309)] - Material: Steel
# Elemento 22 procesado correctamente.
# Recuperando nodos para el triángulo 23 con ids: [214 222 215 308 309 284]
# Triángulo 23 - Nodos: [np.int32(215), np.int32(223), np.int32(216), np.int32(309), np.int32(310), np.int32(285)] - Material: Steel
# Elemento 23 - Nodos: [np.int32(215), np.int32(223), np.int32(216), np.int32(309), np.int32(310), np.int32(285)] - Material: Steel
# Elemento 23 procesado correctamente.
# Recuperando nodos para el triángulo 24 con ids: [215 222 223 309 310 311]
# Triángulo 24 - Nodos: [np.int32(216), np.int32(223), np.int32(224), np.int32(310), np.int32(311), np.int32(312)] - Material: Steel
# Elemento 24 - Nodos: [np.int32(216), np.int32(223), np.int32(224), np.int32(310), np.int32(311), np.int32(312)] - Material: Steel
# Elemento 24 procesado correctamente.
# Recuperando nodos para el triángulo 25 con ids: [215 223 216 311 312 287]
# Triángulo 25 - Nodos: [np.int32(216), np.int32(224), np.int32(217), np.int32(312), np.int32(313), np.int32(288)] - Material: Steel
# Elemento 25 - Nodos: [np.int32(216), np.int32(224), np.int32(217), np.int32(312), np.int32(313), np.int32(288)] - Material: Steel
# Elemento 25 procesado correctamente.
# Recuperando nodos para el triángulo 26 con ids: [216 223 224 312 313 314]
# Triángulo 26 - Nodos: [np.int32(217), np.int32(224), np.int32(225), np.int32(313), np.int32(314), np.int32(315)] - Material: Steel
# Elemento 26 - Nodos: [np.int32(217), np.int32(224), np.int32(225), np.int32(313), np.int32(314), np.int32(315)] - Material: Steel
# Elemento 26 procesado correctamente.
# Recuperando nodos para el triángulo 27 con ids: [216 224 217 314 315 290]
# Triángulo 27 - Nodos: [np.int32(217), np.int32(225), np.int32(218), np.int32(315), np.int32(316), np.int32(291)] - Material: Steel
# Elemento 27 - Nodos: [np.int32(217), np.int32(225), np.int32(218), np.int32(315), np.int32(316), np.int32(291)] - Material: Steel
# Elemento 27 procesado correctamente.
# Recuperando nodos para el triángulo 28 con ids: [217 224 225 315 316 317]
# Triángulo 28 - Nodos: [np.int32(218), np.int32(225), np.int32(226), np.int32(316), np.int32(317), np.int32(318)] - Material: Steel
# Elemento 28 - Nodos: [np.int32(218), np.int32(225), np.int32(226), np.int32(316), np.int32(317), np.int32(318)] - Material: Steel
# Elemento 28 procesado correctamente.
# Recuperando nodos para el triángulo 29 con ids: [217 225 218 317 318 293]
# Triángulo 29 - Nodos: [np.int32(218), np.int32(226), np.int32(219), np.int32(318), np.int32(319), np.int32(294)] - Material: Steel
# Elemento 29 - Nodos: [np.int32(218), np.int32(226), np.int32(219), np.int32(318), np.int32(319), np.int32(294)] - Material: Steel
# Elemento 29 procesado correctamente.
# Recuperando nodos para el triángulo 30 con ids: [218 225 226 318 319 320]
# Triángulo 30 - Nodos: [np.int32(219), np.int32(226), np.int32(227), np.int32(319), np.int32(320), np.int32(321)] - Material: Steel
# Elemento 30 - Nodos: [np.int32(219), np.int32(226), np.int32(227), np.int32(319), np.int32(320), np.int32(321)] - Material: Steel
# Elemento 30 procesado correctamente.
# Recuperando nodos para el triángulo 31 con ids: [218 226 219 320 321 296]
# Triángulo 31 - Nodos: [np.int32(219), np.int32(227), np.int32(220), np.int32(321), np.int32(322), np.int32(297)] - Material: Steel
# Elemento 31 - Nodos: [np.int32(219), np.int32(227), np.int32(220), np.int32(321), np.int32(322), np.int32(297)] - Material: Steel
# Elemento 31 procesado correctamente.
# Recuperando nodos para el triángulo 32 con ids: [219 226 227 321 322 323]
# Triángulo 32 - Nodos: [np.int32(220), np.int32(227), np.int32(228), np.int32(322), np.int32(323), np.int32(324)] - Material: Steel
# Elemento 32 - Nodos: [np.int32(220), np.int32(227), np.int32(228), np.int32(322), np.int32(323), np.int32(324)] - Material: Steel
# Elemento 32 procesado correctamente.
# Recuperando nodos para el triángulo 33 con ids: [219 227 220 323 324 299]
# Triángulo 33 - Nodos: [np.int32(220), np.int32(228), np.int32(221), np.int32(324), np.int32(325), np.int32(300)] - Material: Steel
# Elemento 33 - Nodos: [np.int32(220), np.int32(228), np.int32(221), np.int32(324), np.int32(325), np.int32(300)] - Material: Steel
# Elemento 33 procesado correctamente.
# Recuperando nodos para el triángulo 34 con ids: [220 227 228 324 325 326]
# Triángulo 34 - Nodos: [np.int32(221), np.int32(228), np.int32(229), np.int32(325), np.int32(326), np.int32(327)] - Material: Steel
# Elemento 34 - Nodos: [np.int32(221), np.int32(228), np.int32(229), np.int32(325), np.int32(326), np.int32(327)] - Material: Steel
# Elemento 34 procesado correctamente.
# Recuperando nodos para el triángulo 35 con ids: [220 228 145 326 327 302]
# Triángulo 35 - Nodos: [np.int32(221), np.int32(229), np.int32(146), np.int32(327), np.int32(328), np.int32(303)] - Material: Steel
# Elemento 35 - Nodos: [np.int32(221), np.int32(229), np.int32(146), np.int32(327), np.int32(328), np.int32(303)] - Material: Steel
# Elemento 35 procesado correctamente.
# Recuperando nodos para el triángulo 36 con ids: [145 228 146 327 328 154]
# Triángulo 36 - Nodos: [np.int32(146), np.int32(229), np.int32(147), np.int32(328), np.int32(329), np.int32(155)] - Material: Steel
# Elemento 36 - Nodos: [np.int32(146), np.int32(229), np.int32(147), np.int32(328), np.int32(329), np.int32(155)] - Material: Steel
# Elemento 36 procesado correctamente.
# Recuperando nodos para el triángulo 37 con ids: [ 10  11 221  19 329 304]
# Triángulo 37 - Nodos: [np.int32(11), np.int32(12), np.int32(222), np.int32(20), np.int32(330), np.int32(305)] - Material: Steel
# Elemento 37 - Nodos: [np.int32(11), np.int32(12), np.int32(222), np.int32(20), np.int32(330), np.int32(305)] - Material: Steel
# Elemento 37 procesado correctamente.
# Recuperando nodos para el triángulo 38 con ids: [221  11 229 329 330 331]
# Triángulo 38 - Nodos: [np.int32(222), np.int32(12), np.int32(230), np.int32(330), np.int32(331), np.int32(332)] - Material: Steel
# Elemento 38 - Nodos: [np.int32(222), np.int32(12), np.int32(230), np.int32(330), np.int32(331), np.int32(332)] - Material: Steel
# Elemento 38 procesado correctamente.
# Recuperando nodos para el triángulo 39 con ids: [221 229 222 331 332 307]
# Triángulo 39 - Nodos: [np.int32(222), np.int32(230), np.int32(223), np.int32(332), np.int32(333), np.int32(308)] - Material: Steel
# Elemento 39 - Nodos: [np.int32(222), np.int32(230), np.int32(223), np.int32(332), np.int32(333), np.int32(308)] - Material: Steel
# Elemento 39 procesado correctamente.
# Recuperando nodos para el triángulo 40 con ids: [222 229 230 332 333 334]
# Triángulo 40 - Nodos: [np.int32(223), np.int32(230), np.int32(231), np.int32(333), np.int32(334), np.int32(335)] - Material: Steel
# Elemento 40 - Nodos: [np.int32(223), np.int32(230), np.int32(231), np.int32(333), np.int32(334), np.int32(335)] - Material: Steel
# Elemento 40 procesado correctamente.
# Recuperando nodos para el triángulo 41 con ids: [222 230 223 334 335 310]
# Triángulo 41 - Nodos: [np.int32(223), np.int32(231), np.int32(224), np.int32(335), np.int32(336), np.int32(311)] - Material: Steel
# Elemento 41 - Nodos: [np.int32(223), np.int32(231), np.int32(224), np.int32(335), np.int32(336), np.int32(311)] - Material: Steel
# Elemento 41 procesado correctamente.
# Recuperando nodos para el triángulo 42 con ids: [223 230 231 335 336 337]
# Triángulo 42 - Nodos: [np.int32(224), np.int32(231), np.int32(232), np.int32(336), np.int32(337), np.int32(338)] - Material: Steel
# Elemento 42 - Nodos: [np.int32(224), np.int32(231), np.int32(232), np.int32(336), np.int32(337), np.int32(338)] - Material: Steel
# Elemento 42 procesado correctamente.
# Recuperando nodos para el triángulo 43 con ids: [223 231 224 337 338 313]
# Triángulo 43 - Nodos: [np.int32(224), np.int32(232), np.int32(225), np.int32(338), np.int32(339), np.int32(314)] - Material: Steel
# Elemento 43 - Nodos: [np.int32(224), np.int32(232), np.int32(225), np.int32(338), np.int32(339), np.int32(314)] - Material: Steel
# Elemento 43 procesado correctamente.
# Recuperando nodos para el triángulo 44 con ids: [224 231 232 338 339 340]
# Triángulo 44 - Nodos: [np.int32(225), np.int32(232), np.int32(233), np.int32(339), np.int32(340), np.int32(341)] - Material: Steel
# Elemento 44 - Nodos: [np.int32(225), np.int32(232), np.int32(233), np.int32(339), np.int32(340), np.int32(341)] - Material: Steel
# Elemento 44 procesado correctamente.
# Recuperando nodos para el triángulo 45 con ids: [224 232 225 340 341 316]
# Triángulo 45 - Nodos: [np.int32(225), np.int32(233), np.int32(226), np.int32(341), np.int32(342), np.int32(317)] - Material: Steel
# Elemento 45 - Nodos: [np.int32(225), np.int32(233), np.int32(226), np.int32(341), np.int32(342), np.int32(317)] - Material: Steel
# Elemento 45 procesado correctamente.
# Recuperando nodos para el triángulo 46 con ids: [225 232 233 341 342 343]
# Triángulo 46 - Nodos: [np.int32(226), np.int32(233), np.int32(234), np.int32(342), np.int32(343), np.int32(344)] - Material: Steel
# Elemento 46 - Nodos: [np.int32(226), np.int32(233), np.int32(234), np.int32(342), np.int32(343), np.int32(344)] - Material: Steel
# Elemento 46 procesado correctamente.
# Recuperando nodos para el triángulo 47 con ids: [225 233 226 343 344 319]
# Triángulo 47 - Nodos: [np.int32(226), np.int32(234), np.int32(227), np.int32(344), np.int32(345), np.int32(320)] - Material: Steel
# Elemento 47 - Nodos: [np.int32(226), np.int32(234), np.int32(227), np.int32(344), np.int32(345), np.int32(320)] - Material: Steel
# Elemento 47 procesado correctamente.
# Recuperando nodos para el triángulo 48 con ids: [226 233 234 344 345 346]
# Triángulo 48 - Nodos: [np.int32(227), np.int32(234), np.int32(235), np.int32(345), np.int32(346), np.int32(347)] - Material: Steel
# Elemento 48 - Nodos: [np.int32(227), np.int32(234), np.int32(235), np.int32(345), np.int32(346), np.int32(347)] - Material: Steel
# Elemento 48 procesado correctamente.
# Recuperando nodos para el triángulo 49 con ids: [226 234 227 346 347 322]
# Triángulo 49 - Nodos: [np.int32(227), np.int32(235), np.int32(228), np.int32(347), np.int32(348), np.int32(323)] - Material: Steel
# Elemento 49 - Nodos: [np.int32(227), np.int32(235), np.int32(228), np.int32(347), np.int32(348), np.int32(323)] - Material: Steel
# Elemento 49 procesado correctamente.
# Recuperando nodos para el triángulo 50 con ids: [227 234 235 347 348 349]
# Triángulo 50 - Nodos: [np.int32(228), np.int32(235), np.int32(236), np.int32(348), np.int32(349), np.int32(350)] - Material: Steel
# Elemento 50 - Nodos: [np.int32(228), np.int32(235), np.int32(236), np.int32(348), np.int32(349), np.int32(350)] - Material: Steel
# Elemento 50 procesado correctamente.
# Recuperando nodos para el triángulo 51 con ids: [227 235 228 349 350 325]
# Triángulo 51 - Nodos: [np.int32(228), np.int32(236), np.int32(229), np.int32(350), np.int32(351), np.int32(326)] - Material: Steel
# Elemento 51 - Nodos: [np.int32(228), np.int32(236), np.int32(229), np.int32(350), np.int32(351), np.int32(326)] - Material: Steel
# Elemento 51 procesado correctamente.
# Recuperando nodos para el triángulo 52 con ids: [228 235 236 350 351 352]
# Triángulo 52 - Nodos: [np.int32(229), np.int32(236), np.int32(237), np.int32(351), np.int32(352), np.int32(353)] - Material: Steel
# Elemento 52 - Nodos: [np.int32(229), np.int32(236), np.int32(237), np.int32(351), np.int32(352), np.int32(353)] - Material: Steel
# Elemento 52 procesado correctamente.
# Recuperando nodos para el triángulo 53 con ids: [228 236 146 352 353 328]
# Triángulo 53 - Nodos: [np.int32(229), np.int32(237), np.int32(147), np.int32(353), np.int32(354), np.int32(329)] - Material: Steel
# Elemento 53 - Nodos: [np.int32(229), np.int32(237), np.int32(147), np.int32(353), np.int32(354), np.int32(329)] - Material: Steel
# Elemento 53 procesado correctamente.
# Recuperando nodos para el triángulo 54 con ids: [146 236 147 353 354 155]
# Triángulo 54 - Nodos: [np.int32(147), np.int32(237), np.int32(148), np.int32(354), np.int32(355), np.int32(156)] - Material: Steel
# Elemento 54 - Nodos: [np.int32(147), np.int32(237), np.int32(148), np.int32(354), np.int32(355), np.int32(156)] - Material: Steel
# Elemento 54 procesado correctamente.
# Recuperando nodos para el triángulo 55 con ids: [ 11  12 229  20 355 330]
# Triángulo 55 - Nodos: [np.int32(12), np.int32(13), np.int32(230), np.int32(21), np.int32(356), np.int32(331)] - Material: Steel
# Elemento 55 - Nodos: [np.int32(12), np.int32(13), np.int32(230), np.int32(21), np.int32(356), np.int32(331)] - Material: Steel
# Elemento 55 procesado correctamente.
# Recuperando nodos para el triángulo 56 con ids: [229  12 237 355 356 357]
# Triángulo 56 - Nodos: [np.int32(230), np.int32(13), np.int32(238), np.int32(356), np.int32(357), np.int32(358)] - Material: Steel
# Elemento 56 - Nodos: [np.int32(230), np.int32(13), np.int32(238), np.int32(356), np.int32(357), np.int32(358)] - Material: Steel
# Elemento 56 procesado correctamente.
# Recuperando nodos para el triángulo 57 con ids: [229 237 230 357 358 333]
# Triángulo 57 - Nodos: [np.int32(230), np.int32(238), np.int32(231), np.int32(358), np.int32(359), np.int32(334)] - Material: Steel
# Elemento 57 - Nodos: [np.int32(230), np.int32(238), np.int32(231), np.int32(358), np.int32(359), np.int32(334)] - Material: Steel
# Elemento 57 procesado correctamente.
# Recuperando nodos para el triángulo 58 con ids: [230 237 238 358 359 360]
# Triángulo 58 - Nodos: [np.int32(231), np.int32(238), np.int32(239), np.int32(359), np.int32(360), np.int32(361)] - Material: Steel
# Elemento 58 - Nodos: [np.int32(231), np.int32(238), np.int32(239), np.int32(359), np.int32(360), np.int32(361)] - Material: Steel
# Elemento 58 procesado correctamente.
# Recuperando nodos para el triángulo 59 con ids: [230 238 231 360 361 336]
# Triángulo 59 - Nodos: [np.int32(231), np.int32(239), np.int32(232), np.int32(361), np.int32(362), np.int32(337)] - Material: Steel
# Elemento 59 - Nodos: [np.int32(231), np.int32(239), np.int32(232), np.int32(361), np.int32(362), np.int32(337)] - Material: Steel
# Elemento 59 procesado correctamente.
# Recuperando nodos para el triángulo 60 con ids: [231 238 239 361 362 363]
# Triángulo 60 - Nodos: [np.int32(232), np.int32(239), np.int32(240), np.int32(362), np.int32(363), np.int32(364)] - Material: Steel
# Elemento 60 - Nodos: [np.int32(232), np.int32(239), np.int32(240), np.int32(362), np.int32(363), np.int32(364)] - Material: Steel
# Elemento 60 procesado correctamente.
# Recuperando nodos para el triángulo 61 con ids: [231 239 232 363 364 339]
# Triángulo 61 - Nodos: [np.int32(232), np.int32(240), np.int32(233), np.int32(364), np.int32(365), np.int32(340)] - Material: Steel
# Elemento 61 - Nodos: [np.int32(232), np.int32(240), np.int32(233), np.int32(364), np.int32(365), np.int32(340)] - Material: Steel
# Elemento 61 procesado correctamente.
# Recuperando nodos para el triángulo 62 con ids: [232 239 240 364 365 366]
# Triángulo 62 - Nodos: [np.int32(233), np.int32(240), np.int32(241), np.int32(365), np.int32(366), np.int32(367)] - Material: Steel
# Elemento 62 - Nodos: [np.int32(233), np.int32(240), np.int32(241), np.int32(365), np.int32(366), np.int32(367)] - Material: Steel
# Elemento 62 procesado correctamente.
# Recuperando nodos para el triángulo 63 con ids: [232 240 233 366 367 342]
# Triángulo 63 - Nodos: [np.int32(233), np.int32(241), np.int32(234), np.int32(367), np.int32(368), np.int32(343)] - Material: Steel
# Elemento 63 - Nodos: [np.int32(233), np.int32(241), np.int32(234), np.int32(367), np.int32(368), np.int32(343)] - Material: Steel
# Elemento 63 procesado correctamente.
# Recuperando nodos para el triángulo 64 con ids: [233 240 241 367 368 369]
# Triángulo 64 - Nodos: [np.int32(234), np.int32(241), np.int32(242), np.int32(368), np.int32(369), np.int32(370)] - Material: Steel
# Elemento 64 - Nodos: [np.int32(234), np.int32(241), np.int32(242), np.int32(368), np.int32(369), np.int32(370)] - Material: Steel
# Elemento 64 procesado correctamente.
# Recuperando nodos para el triángulo 65 con ids: [233 241 234 369 370 345]
# Triángulo 65 - Nodos: [np.int32(234), np.int32(242), np.int32(235), np.int32(370), np.int32(371), np.int32(346)] - Material: Steel
# Elemento 65 - Nodos: [np.int32(234), np.int32(242), np.int32(235), np.int32(370), np.int32(371), np.int32(346)] - Material: Steel
# Elemento 65 procesado correctamente.
# Recuperando nodos para el triángulo 66 con ids: [234 241 242 370 371 372]
# Triángulo 66 - Nodos: [np.int32(235), np.int32(242), np.int32(243), np.int32(371), np.int32(372), np.int32(373)] - Material: Steel
# Elemento 66 - Nodos: [np.int32(235), np.int32(242), np.int32(243), np.int32(371), np.int32(372), np.int32(373)] - Material: Steel
# Elemento 66 procesado correctamente.
# Recuperando nodos para el triángulo 67 con ids: [234 242 235 372 373 348]
# Triángulo 67 - Nodos: [np.int32(235), np.int32(243), np.int32(236), np.int32(373), np.int32(374), np.int32(349)] - Material: Steel
# Elemento 67 - Nodos: [np.int32(235), np.int32(243), np.int32(236), np.int32(373), np.int32(374), np.int32(349)] - Material: Steel
# Elemento 67 procesado correctamente.
# Recuperando nodos para el triángulo 68 con ids: [235 242 243 373 374 375]
# Triángulo 68 - Nodos: [np.int32(236), np.int32(243), np.int32(244), np.int32(374), np.int32(375), np.int32(376)] - Material: Steel
# Elemento 68 - Nodos: [np.int32(236), np.int32(243), np.int32(244), np.int32(374), np.int32(375), np.int32(376)] - Material: Steel
# Elemento 68 procesado correctamente.
# Recuperando nodos para el triángulo 69 con ids: [235 243 236 375 376 351]
# Triángulo 69 - Nodos: [np.int32(236), np.int32(244), np.int32(237), np.int32(376), np.int32(377), np.int32(352)] - Material: Steel
# Elemento 69 - Nodos: [np.int32(236), np.int32(244), np.int32(237), np.int32(376), np.int32(377), np.int32(352)] - Material: Steel
# Elemento 69 procesado correctamente.
# Recuperando nodos para el triángulo 70 con ids: [236 243 244 376 377 378]
# Triángulo 70 - Nodos: [np.int32(237), np.int32(244), np.int32(245), np.int32(377), np.int32(378), np.int32(379)] - Material: Steel
# Elemento 70 - Nodos: [np.int32(237), np.int32(244), np.int32(245), np.int32(377), np.int32(378), np.int32(379)] - Material: Steel
# Elemento 70 procesado correctamente.
# Recuperando nodos para el triángulo 71 con ids: [236 244 147 378 379 354]
# Triángulo 71 - Nodos: [np.int32(237), np.int32(245), np.int32(148), np.int32(379), np.int32(380), np.int32(355)] - Material: Steel
# Elemento 71 - Nodos: [np.int32(237), np.int32(245), np.int32(148), np.int32(379), np.int32(380), np.int32(355)] - Material: Steel
# Elemento 71 procesado correctamente.
# Recuperando nodos para el triángulo 72 con ids: [147 244 148 379 380 156]
# Triángulo 72 - Nodos: [np.int32(148), np.int32(245), np.int32(149), np.int32(380), np.int32(381), np.int32(157)] - Material: Steel
# Elemento 72 - Nodos: [np.int32(148), np.int32(245), np.int32(149), np.int32(380), np.int32(381), np.int32(157)] - Material: Steel
# Elemento 72 procesado correctamente.
# Recuperando nodos para el triángulo 73 con ids: [ 12  13 237  21 381 356]
# Triángulo 73 - Nodos: [np.int32(13), np.int32(14), np.int32(238), np.int32(22), np.int32(382), np.int32(357)] - Material: Steel
# Elemento 73 - Nodos: [np.int32(13), np.int32(14), np.int32(238), np.int32(22), np.int32(382), np.int32(357)] - Material: Steel
# Elemento 73 procesado correctamente.
# Recuperando nodos para el triángulo 74 con ids: [237  13 245 381 382 383]
# Triángulo 74 - Nodos: [np.int32(238), np.int32(14), np.int32(246), np.int32(382), np.int32(383), np.int32(384)] - Material: Steel
# Elemento 74 - Nodos: [np.int32(238), np.int32(14), np.int32(246), np.int32(382), np.int32(383), np.int32(384)] - Material: Steel
# Elemento 74 procesado correctamente.
# Recuperando nodos para el triángulo 75 con ids: [237 245 238 383 384 359]
# Triángulo 75 - Nodos: [np.int32(238), np.int32(246), np.int32(239), np.int32(384), np.int32(385), np.int32(360)] - Material: Steel
# Elemento 75 - Nodos: [np.int32(238), np.int32(246), np.int32(239), np.int32(384), np.int32(385), np.int32(360)] - Material: Steel
# Elemento 75 procesado correctamente.
# Recuperando nodos para el triángulo 76 con ids: [238 245 246 384 385 386]
# Triángulo 76 - Nodos: [np.int32(239), np.int32(246), np.int32(247), np.int32(385), np.int32(386), np.int32(387)] - Material: Steel
# Elemento 76 - Nodos: [np.int32(239), np.int32(246), np.int32(247), np.int32(385), np.int32(386), np.int32(387)] - Material: Steel
# Elemento 76 procesado correctamente.
# Recuperando nodos para el triángulo 77 con ids: [238 246 239 386 387 362]
# Triángulo 77 - Nodos: [np.int32(239), np.int32(247), np.int32(240), np.int32(387), np.int32(388), np.int32(363)] - Material: Steel
# Elemento 77 - Nodos: [np.int32(239), np.int32(247), np.int32(240), np.int32(387), np.int32(388), np.int32(363)] - Material: Steel
# Elemento 77 procesado correctamente.
# Recuperando nodos para el triángulo 78 con ids: [239 246 247 387 388 389]
# Triángulo 78 - Nodos: [np.int32(240), np.int32(247), np.int32(248), np.int32(388), np.int32(389), np.int32(390)] - Material: Steel
# Elemento 78 - Nodos: [np.int32(240), np.int32(247), np.int32(248), np.int32(388), np.int32(389), np.int32(390)] - Material: Steel
# Elemento 78 procesado correctamente.
# Recuperando nodos para el triángulo 79 con ids: [239 247 240 389 390 365]
# Triángulo 79 - Nodos: [np.int32(240), np.int32(248), np.int32(241), np.int32(390), np.int32(391), np.int32(366)] - Material: Steel
# Elemento 79 - Nodos: [np.int32(240), np.int32(248), np.int32(241), np.int32(390), np.int32(391), np.int32(366)] - Material: Steel
# Elemento 79 procesado correctamente.
# Recuperando nodos para el triángulo 80 con ids: [240 247 248 390 391 392]
# Triángulo 80 - Nodos: [np.int32(241), np.int32(248), np.int32(249), np.int32(391), np.int32(392), np.int32(393)] - Material: Steel
# Elemento 80 - Nodos: [np.int32(241), np.int32(248), np.int32(249), np.int32(391), np.int32(392), np.int32(393)] - Material: Steel
# Elemento 80 procesado correctamente.
# Recuperando nodos para el triángulo 81 con ids: [240 248 241 392 393 368]
# Triángulo 81 - Nodos: [np.int32(241), np.int32(249), np.int32(242), np.int32(393), np.int32(394), np.int32(369)] - Material: Steel
# Elemento 81 - Nodos: [np.int32(241), np.int32(249), np.int32(242), np.int32(393), np.int32(394), np.int32(369)] - Material: Steel
# Elemento 81 procesado correctamente.
# Recuperando nodos para el triángulo 82 con ids: [241 248 249 393 394 395]
# Triángulo 82 - Nodos: [np.int32(242), np.int32(249), np.int32(250), np.int32(394), np.int32(395), np.int32(396)] - Material: Steel
# Elemento 82 - Nodos: [np.int32(242), np.int32(249), np.int32(250), np.int32(394), np.int32(395), np.int32(396)] - Material: Steel
# Elemento 82 procesado correctamente.
# Recuperando nodos para el triángulo 83 con ids: [241 249 242 395 396 371]
# Triángulo 83 - Nodos: [np.int32(242), np.int32(250), np.int32(243), np.int32(396), np.int32(397), np.int32(372)] - Material: Steel
# Elemento 83 - Nodos: [np.int32(242), np.int32(250), np.int32(243), np.int32(396), np.int32(397), np.int32(372)] - Material: Steel
# Elemento 83 procesado correctamente.
# Recuperando nodos para el triángulo 84 con ids: [242 249 250 396 397 398]
# Triángulo 84 - Nodos: [np.int32(243), np.int32(250), np.int32(251), np.int32(397), np.int32(398), np.int32(399)] - Material: Steel
# Elemento 84 - Nodos: [np.int32(243), np.int32(250), np.int32(251), np.int32(397), np.int32(398), np.int32(399)] - Material: Steel
# Elemento 84 procesado correctamente.
# Recuperando nodos para el triángulo 85 con ids: [242 250 243 398 399 374]
# Triángulo 85 - Nodos: [np.int32(243), np.int32(251), np.int32(244), np.int32(399), np.int32(400), np.int32(375)] - Material: Steel
# Elemento 85 - Nodos: [np.int32(243), np.int32(251), np.int32(244), np.int32(399), np.int32(400), np.int32(375)] - Material: Steel
# Elemento 85 procesado correctamente.
# Recuperando nodos para el triángulo 86 con ids: [243 250 251 399 400 401]
# Triángulo 86 - Nodos: [np.int32(244), np.int32(251), np.int32(252), np.int32(400), np.int32(401), np.int32(402)] - Material: Steel
# Elemento 86 - Nodos: [np.int32(244), np.int32(251), np.int32(252), np.int32(400), np.int32(401), np.int32(402)] - Material: Steel
# Elemento 86 procesado correctamente.
# Recuperando nodos para el triángulo 87 con ids: [243 251 244 401 402 377]
# Triángulo 87 - Nodos: [np.int32(244), np.int32(252), np.int32(245), np.int32(402), np.int32(403), np.int32(378)] - Material: Steel
# Elemento 87 - Nodos: [np.int32(244), np.int32(252), np.int32(245), np.int32(402), np.int32(403), np.int32(378)] - Material: Steel
# Elemento 87 procesado correctamente.
# Recuperando nodos para el triángulo 88 con ids: [244 251 252 402 403 404]
# Triángulo 88 - Nodos: [np.int32(245), np.int32(252), np.int32(253), np.int32(403), np.int32(404), np.int32(405)] - Material: Steel
# Elemento 88 - Nodos: [np.int32(245), np.int32(252), np.int32(253), np.int32(403), np.int32(404), np.int32(405)] - Material: Steel
# Elemento 88 procesado correctamente.
# Recuperando nodos para el triángulo 89 con ids: [244 252 148 404 405 380]
# Triángulo 89 - Nodos: [np.int32(245), np.int32(253), np.int32(149), np.int32(405), np.int32(406), np.int32(381)] - Material: Steel
# Elemento 89 - Nodos: [np.int32(245), np.int32(253), np.int32(149), np.int32(405), np.int32(406), np.int32(381)] - Material: Steel
# Elemento 89 procesado correctamente.
# Recuperando nodos para el triángulo 90 con ids: [148 252 149 405 406 157]
# Triángulo 90 - Nodos: [np.int32(149), np.int32(253), np.int32(150), np.int32(406), np.int32(407), np.int32(158)] - Material: Steel
# Elemento 90 - Nodos: [np.int32(149), np.int32(253), np.int32(150), np.int32(406), np.int32(407), np.int32(158)] - Material: Steel
# Elemento 90 procesado correctamente.
# Recuperando nodos para el triángulo 91 con ids: [ 13  14 245  22 407 382]
# Triángulo 91 - Nodos: [np.int32(14), np.int32(15), np.int32(246), np.int32(23), np.int32(408), np.int32(383)] - Material: Steel
# Elemento 91 - Nodos: [np.int32(14), np.int32(15), np.int32(246), np.int32(23), np.int32(408), np.int32(383)] - Material: Steel
# Elemento 91 procesado correctamente.
# Recuperando nodos para el triángulo 92 con ids: [245  14 253 407 408 409]
# Triángulo 92 - Nodos: [np.int32(246), np.int32(15), np.int32(254), np.int32(408), np.int32(409), np.int32(410)] - Material: Steel
# Elemento 92 - Nodos: [np.int32(246), np.int32(15), np.int32(254), np.int32(408), np.int32(409), np.int32(410)] - Material: Steel
# Elemento 92 procesado correctamente.
# Recuperando nodos para el triángulo 93 con ids: [245 253 246 409 410 385]
# Triángulo 93 - Nodos: [np.int32(246), np.int32(254), np.int32(247), np.int32(410), np.int32(411), np.int32(386)] - Material: Steel
# Elemento 93 - Nodos: [np.int32(246), np.int32(254), np.int32(247), np.int32(410), np.int32(411), np.int32(386)] - Material: Steel
# Elemento 93 procesado correctamente.
# Recuperando nodos para el triángulo 94 con ids: [246 253 254 410 411 412]
# Triángulo 94 - Nodos: [np.int32(247), np.int32(254), np.int32(255), np.int32(411), np.int32(412), np.int32(413)] - Material: Steel
# Elemento 94 - Nodos: [np.int32(247), np.int32(254), np.int32(255), np.int32(411), np.int32(412), np.int32(413)] - Material: Steel
# Elemento 94 procesado correctamente.
# Recuperando nodos para el triángulo 95 con ids: [246 254 247 412 413 388]
# Triángulo 95 - Nodos: [np.int32(247), np.int32(255), np.int32(248), np.int32(413), np.int32(414), np.int32(389)] - Material: Steel
# Elemento 95 - Nodos: [np.int32(247), np.int32(255), np.int32(248), np.int32(413), np.int32(414), np.int32(389)] - Material: Steel
# Elemento 95 procesado correctamente.
# Recuperando nodos para el triángulo 96 con ids: [247 254 255 413 414 415]
# Triángulo 96 - Nodos: [np.int32(248), np.int32(255), np.int32(256), np.int32(414), np.int32(415), np.int32(416)] - Material: Steel
# Elemento 96 - Nodos: [np.int32(248), np.int32(255), np.int32(256), np.int32(414), np.int32(415), np.int32(416)] - Material: Steel
# Elemento 96 procesado correctamente.
# Recuperando nodos para el triángulo 97 con ids: [247 255 248 415 416 391]
# Triángulo 97 - Nodos: [np.int32(248), np.int32(256), np.int32(249), np.int32(416), np.int32(417), np.int32(392)] - Material: Steel
# Elemento 97 - Nodos: [np.int32(248), np.int32(256), np.int32(249), np.int32(416), np.int32(417), np.int32(392)] - Material: Steel
# Elemento 97 procesado correctamente.
# Recuperando nodos para el triángulo 98 con ids: [248 255 256 416 417 418]
# Triángulo 98 - Nodos: [np.int32(249), np.int32(256), np.int32(257), np.int32(417), np.int32(418), np.int32(419)] - Material: Steel
# Elemento 98 - Nodos: [np.int32(249), np.int32(256), np.int32(257), np.int32(417), np.int32(418), np.int32(419)] - Material: Steel
# Elemento 98 procesado correctamente.
# Recuperando nodos para el triángulo 99 con ids: [248 256 249 418 419 394]
# Triángulo 99 - Nodos: [np.int32(249), np.int32(257), np.int32(250), np.int32(419), np.int32(420), np.int32(395)] - Material: Steel
# Elemento 99 - Nodos: [np.int32(249), np.int32(257), np.int32(250), np.int32(419), np.int32(420), np.int32(395)] - Material: Steel
# Elemento 99 procesado correctamente.
# Recuperando nodos para el triángulo 100 con ids: [249 256 257 419 420 421]
# Triángulo 100 - Nodos: [np.int32(250), np.int32(257), np.int32(258), np.int32(420), np.int32(421), np.int32(422)] - Material: Steel
# Elemento 100 - Nodos: [np.int32(250), np.int32(257), np.int32(258), np.int32(420), np.int32(421), np.int32(422)] - Material: Steel
# Elemento 100 procesado correctamente.
# Recuperando nodos para el triángulo 101 con ids: [249 257 250 421 422 397]
# Triángulo 101 - Nodos: [np.int32(250), np.int32(258), np.int32(251), np.int32(422), np.int32(423), np.int32(398)] - Material: Steel
# Elemento 101 - Nodos: [np.int32(250), np.int32(258), np.int32(251), np.int32(422), np.int32(423), np.int32(398)] - Material: Steel
# Elemento 101 procesado correctamente.
# Recuperando nodos para el triángulo 102 con ids: [250 257 258 422 423 424]
# Triángulo 102 - Nodos: [np.int32(251), np.int32(258), np.int32(259), np.int32(423), np.int32(424), np.int32(425)] - Material: Steel
# Elemento 102 - Nodos: [np.int32(251), np.int32(258), np.int32(259), np.int32(423), np.int32(424), np.int32(425)] - Material: Steel
# Elemento 102 procesado correctamente.
# Recuperando nodos para el triángulo 103 con ids: [250 258 251 424 425 400]
# Triángulo 103 - Nodos: [np.int32(251), np.int32(259), np.int32(252), np.int32(425), np.int32(426), np.int32(401)] - Material: Steel
# Elemento 103 - Nodos: [np.int32(251), np.int32(259), np.int32(252), np.int32(425), np.int32(426), np.int32(401)] - Material: Steel
# Elemento 103 procesado correctamente.
# Recuperando nodos para el triángulo 104 con ids: [251 258 259 425 426 427]
# Triángulo 104 - Nodos: [np.int32(252), np.int32(259), np.int32(260), np.int32(426), np.int32(427), np.int32(428)] - Material: Steel
# Elemento 104 - Nodos: [np.int32(252), np.int32(259), np.int32(260), np.int32(426), np.int32(427), np.int32(428)] - Material: Steel
# Elemento 104 procesado correctamente.
# Recuperando nodos para el triángulo 105 con ids: [251 259 252 427 428 403]
# Triángulo 105 - Nodos: [np.int32(252), np.int32(260), np.int32(253), np.int32(428), np.int32(429), np.int32(404)] - Material: Steel
# Elemento 105 - Nodos: [np.int32(252), np.int32(260), np.int32(253), np.int32(428), np.int32(429), np.int32(404)] - Material: Steel
# Elemento 105 procesado correctamente.
# Recuperando nodos para el triángulo 106 con ids: [252 259 260 428 429 430]
# Triángulo 106 - Nodos: [np.int32(253), np.int32(260), np.int32(261), np.int32(429), np.int32(430), np.int32(431)] - Material: Steel
# Elemento 106 - Nodos: [np.int32(253), np.int32(260), np.int32(261), np.int32(429), np.int32(430), np.int32(431)] - Material: Steel
# Elemento 106 procesado correctamente.
# Recuperando nodos para el triángulo 107 con ids: [252 260 149 430 431 406]
# Triángulo 107 - Nodos: [np.int32(253), np.int32(261), np.int32(150), np.int32(431), np.int32(432), np.int32(407)] - Material: Steel
# Elemento 107 - Nodos: [np.int32(253), np.int32(261), np.int32(150), np.int32(431), np.int32(432), np.int32(407)] - Material: Steel
# Elemento 107 procesado correctamente.
# Recuperando nodos para el triángulo 108 con ids: [149 260 150 431 432 158]
# Triángulo 108 - Nodos: [np.int32(150), np.int32(261), np.int32(151), np.int32(432), np.int32(433), np.int32(159)] - Material: Steel
# Elemento 108 - Nodos: [np.int32(150), np.int32(261), np.int32(151), np.int32(432), np.int32(433), np.int32(159)] - Material: Steel
# Elemento 108 procesado correctamente.
# Recuperando nodos para el triángulo 109 con ids: [ 14  15 253  23 433 408]
# Triángulo 109 - Nodos: [np.int32(15), np.int32(16), np.int32(254), np.int32(24), np.int32(434), np.int32(409)] - Material: Steel
# Elemento 109 - Nodos: [np.int32(15), np.int32(16), np.int32(254), np.int32(24), np.int32(434), np.int32(409)] - Material: Steel
# Elemento 109 procesado correctamente.
# Recuperando nodos para el triángulo 110 con ids: [253  15 261 433 434 435]
# Triángulo 110 - Nodos: [np.int32(254), np.int32(16), np.int32(262), np.int32(434), np.int32(435), np.int32(436)] - Material: Steel
# Elemento 110 - Nodos: [np.int32(254), np.int32(16), np.int32(262), np.int32(434), np.int32(435), np.int32(436)] - Material: Steel
# Elemento 110 procesado correctamente.
# Recuperando nodos para el triángulo 111 con ids: [253 261 254 435 436 411]
# Triángulo 111 - Nodos: [np.int32(254), np.int32(262), np.int32(255), np.int32(436), np.int32(437), np.int32(412)] - Material: Steel
# Elemento 111 - Nodos: [np.int32(254), np.int32(262), np.int32(255), np.int32(436), np.int32(437), np.int32(412)] - Material: Steel
# Elemento 111 procesado correctamente.
# Recuperando nodos para el triángulo 112 con ids: [254 261 262 436 437 438]
# Triángulo 112 - Nodos: [np.int32(255), np.int32(262), np.int32(263), np.int32(437), np.int32(438), np.int32(439)] - Material: Steel
# Elemento 112 - Nodos: [np.int32(255), np.int32(262), np.int32(263), np.int32(437), np.int32(438), np.int32(439)] - Material: Steel
# Elemento 112 procesado correctamente.
# Recuperando nodos para el triángulo 113 con ids: [254 262 255 438 439 414]
# Triángulo 113 - Nodos: [np.int32(255), np.int32(263), np.int32(256), np.int32(439), np.int32(440), np.int32(415)] - Material: Steel
# Elemento 113 - Nodos: [np.int32(255), np.int32(263), np.int32(256), np.int32(439), np.int32(440), np.int32(415)] - Material: Steel
# Elemento 113 procesado correctamente.
# Recuperando nodos para el triángulo 114 con ids: [255 262 263 439 440 441]
# Triángulo 114 - Nodos: [np.int32(256), np.int32(263), np.int32(264), np.int32(440), np.int32(441), np.int32(442)] - Material: Steel
# Elemento 114 - Nodos: [np.int32(256), np.int32(263), np.int32(264), np.int32(440), np.int32(441), np.int32(442)] - Material: Steel
# Elemento 114 procesado correctamente.
# Recuperando nodos para el triángulo 115 con ids: [255 263 256 441 442 417]
# Triángulo 115 - Nodos: [np.int32(256), np.int32(264), np.int32(257), np.int32(442), np.int32(443), np.int32(418)] - Material: Steel
# Elemento 115 - Nodos: [np.int32(256), np.int32(264), np.int32(257), np.int32(442), np.int32(443), np.int32(418)] - Material: Steel
# Elemento 115 procesado correctamente.
# Recuperando nodos para el triángulo 116 con ids: [256 263 264 442 443 444]
# Triángulo 116 - Nodos: [np.int32(257), np.int32(264), np.int32(265), np.int32(443), np.int32(444), np.int32(445)] - Material: Steel
# Elemento 116 - Nodos: [np.int32(257), np.int32(264), np.int32(265), np.int32(443), np.int32(444), np.int32(445)] - Material: Steel
# Elemento 116 procesado correctamente.
# Recuperando nodos para el triángulo 117 con ids: [256 264 257 444 445 420]
# Triángulo 117 - Nodos: [np.int32(257), np.int32(265), np.int32(258), np.int32(445), np.int32(446), np.int32(421)] - Material: Steel
# Elemento 117 - Nodos: [np.int32(257), np.int32(265), np.int32(258), np.int32(445), np.int32(446), np.int32(421)] - Material: Steel
# Elemento 117 procesado correctamente.
# Recuperando nodos para el triángulo 118 con ids: [257 264 265 445 446 447]
# Triángulo 118 - Nodos: [np.int32(258), np.int32(265), np.int32(266), np.int32(446), np.int32(447), np.int32(448)] - Material: Steel
# Elemento 118 - Nodos: [np.int32(258), np.int32(265), np.int32(266), np.int32(446), np.int32(447), np.int32(448)] - Material: Steel
# Elemento 118 procesado correctamente.
# Recuperando nodos para el triángulo 119 con ids: [257 265 258 447 448 423]
# Triángulo 119 - Nodos: [np.int32(258), np.int32(266), np.int32(259), np.int32(448), np.int32(449), np.int32(424)] - Material: Steel
# Elemento 119 - Nodos: [np.int32(258), np.int32(266), np.int32(259), np.int32(448), np.int32(449), np.int32(424)] - Material: Steel
# Elemento 119 procesado correctamente.
# Recuperando nodos para el triángulo 120 con ids: [258 265 266 448 449 450]
# Triángulo 120 - Nodos: [np.int32(259), np.int32(266), np.int32(267), np.int32(449), np.int32(450), np.int32(451)] - Material: Steel
# Elemento 120 - Nodos: [np.int32(259), np.int32(266), np.int32(267), np.int32(449), np.int32(450), np.int32(451)] - Material: Steel
# Elemento 120 procesado correctamente.
# Recuperando nodos para el triángulo 121 con ids: [258 266 259 450 451 426]
# Triángulo 121 - Nodos: [np.int32(259), np.int32(267), np.int32(260), np.int32(451), np.int32(452), np.int32(427)] - Material: Steel
# Elemento 121 - Nodos: [np.int32(259), np.int32(267), np.int32(260), np.int32(451), np.int32(452), np.int32(427)] - Material: Steel
# Elemento 121 procesado correctamente.
# Recuperando nodos para el triángulo 122 con ids: [259 266 267 451 452 453]
# Triángulo 122 - Nodos: [np.int32(260), np.int32(267), np.int32(268), np.int32(452), np.int32(453), np.int32(454)] - Material: Steel
# Elemento 122 - Nodos: [np.int32(260), np.int32(267), np.int32(268), np.int32(452), np.int32(453), np.int32(454)] - Material: Steel
# Elemento 122 procesado correctamente.
# Recuperando nodos para el triángulo 123 con ids: [259 267 260 453 454 429]
# Triángulo 123 - Nodos: [np.int32(260), np.int32(268), np.int32(261), np.int32(454), np.int32(455), np.int32(430)] - Material: Steel
# Elemento 123 - Nodos: [np.int32(260), np.int32(268), np.int32(261), np.int32(454), np.int32(455), np.int32(430)] - Material: Steel
# Elemento 123 procesado correctamente.
# Recuperando nodos para el triángulo 124 con ids: [260 267 268 454 455 456]
# Triángulo 124 - Nodos: [np.int32(261), np.int32(268), np.int32(269), np.int32(455), np.int32(456), np.int32(457)] - Material: Steel
# Elemento 124 - Nodos: [np.int32(261), np.int32(268), np.int32(269), np.int32(455), np.int32(456), np.int32(457)] - Material: Steel
# Elemento 124 procesado correctamente.
# Recuperando nodos para el triángulo 125 con ids: [260 268 150 456 457 432]
# Triángulo 125 - Nodos: [np.int32(261), np.int32(269), np.int32(151), np.int32(457), np.int32(458), np.int32(433)] - Material: Steel
# Elemento 125 - Nodos: [np.int32(261), np.int32(269), np.int32(151), np.int32(457), np.int32(458), np.int32(433)] - Material: Steel
# Elemento 125 procesado correctamente.
# Recuperando nodos para el triángulo 126 con ids: [150 268 151 457 458 159]
# Triángulo 126 - Nodos: [np.int32(151), np.int32(269), np.int32(152), np.int32(458), np.int32(459), np.int32(160)] - Material: Steel
# Elemento 126 - Nodos: [np.int32(151), np.int32(269), np.int32(152), np.int32(458), np.int32(459), np.int32(160)] - Material: Steel
# Elemento 126 procesado correctamente.
# Recuperando nodos para el triángulo 127 con ids: [ 15  16 261  24 459 434]
# Triángulo 127 - Nodos: [np.int32(16), np.int32(17), np.int32(262), np.int32(25), np.int32(460), np.int32(435)] - Material: Steel
# Elemento 127 - Nodos: [np.int32(16), np.int32(17), np.int32(262), np.int32(25), np.int32(460), np.int32(435)] - Material: Steel
# Elemento 127 procesado correctamente.
# Recuperando nodos para el triángulo 128 con ids: [261  16 269 459 460 461]
# Triángulo 128 - Nodos: [np.int32(262), np.int32(17), np.int32(270), np.int32(460), np.int32(461), np.int32(462)] - Material: Steel
# Elemento 128 - Nodos: [np.int32(262), np.int32(17), np.int32(270), np.int32(460), np.int32(461), np.int32(462)] - Material: Steel
# Elemento 128 procesado correctamente.
# Recuperando nodos para el triángulo 129 con ids: [261 269 262 461 462 437]
# Triángulo 129 - Nodos: [np.int32(262), np.int32(270), np.int32(263), np.int32(462), np.int32(463), np.int32(438)] - Material: Steel
# Elemento 129 - Nodos: [np.int32(262), np.int32(270), np.int32(263), np.int32(462), np.int32(463), np.int32(438)] - Material: Steel
# ...
# Triángulo 608 - Nodos: [np.int32(1127), np.int32(1134), np.int32(1135), np.int32(1319), np.int32(1320), np.int32(1321)] - Material: Steel
# Elemento 608 - Nodos: [np.int32(1127), np.int32(1134), np.int32(1135), np.int32(1319), np.int32(1320), np.int32(1321)] - Material: Steel
# Elemento 608 procesado correctamente.
# Recuperando nodos para el triángulo 609 con ids: [1126 1134 1127 1320 1321 1296]
# Triángulo 609 - Nodos: [np.int32(1127), np.int32(1135), np.int32(1128), np.int32(1321), np.int32(1322), np.int32(1297)] - Material: Steel
# Elemento 609 - Nodos: [np.int32(1127), np.int32(1135), np.int32(1128), np.int32(1321), np.int32(1322), np.int32(1297)] - Material: Steel
# Elemento 609 procesado correctamente.
# Recuperando nodos para el triángulo 610 con ids: [1127 1134 1135 1321 1322 1323]
# Triángulo 610 - Nodos: [np.int32(1128), np.int32(1135), np.int32(1136), np.int32(1322), np.int32(1323), np.int32(1324)] - Material: Steel
# Elemento 610 - Nodos: [np.int32(1128), np.int32(1135), np.int32(1136), np.int32(1322), np.int32(1323), np.int32(1324)] - Material: Steel
# Elemento 610 procesado correctamente.
# Recuperando nodos para el triángulo 611 con ids: [1127 1135  133 1323 1324 1299]
# Triángulo 611 - Nodos: [np.int32(1128), np.int32(1136), np.int32(134), np.int32(1324), np.int32(1325), np.int32(1300)] - Material: Steel
# Elemento 611 - Nodos: [np.int32(1128), np.int32(1136), np.int32(134), np.int32(1324), np.int32(1325), np.int32(1300)] - Material: Steel
# Elemento 611 procesado correctamente.
# Recuperando nodos para el triángulo 612 con ids: [ 133 1135  134 1324 1325  142]
# Triángulo 612 - Nodos: [np.int32(134), np.int32(1136), np.int32(135), np.int32(1325), np.int32(1326), np.int32(143)] - Material: Steel
# Elemento 612 - Nodos: [np.int32(134), np.int32(1136), np.int32(135), np.int32(1325), np.int32(1326), np.int32(143)] - Material: Steel
# Elemento 612 procesado correctamente.
# Recuperando nodos para el triángulo 613 con ids: [ 202  203 1128  211 1326 1301]
# Triángulo 613 - Nodos: [np.int32(203), np.int32(204), np.int32(1129), np.int32(212), np.int32(1327), np.int32(1302)] - Material: Steel
# Elemento 613 - Nodos: [np.int32(203), np.int32(204), np.int32(1129), np.int32(212), np.int32(1327), np.int32(1302)] - Material: Steel
# Elemento 613 procesado correctamente.
# Recuperando nodos para el triángulo 614 con ids: [1128  203 1136 1326 1327 1328]
# Triángulo 614 - Nodos: [np.int32(1129), np.int32(204), np.int32(1137), np.int32(1327), np.int32(1328), np.int32(1329)] - Material: Steel
# Elemento 614 - Nodos: [np.int32(1129), np.int32(204), np.int32(1137), np.int32(1327), np.int32(1328), np.int32(1329)] - Material: Steel
# Elemento 614 procesado correctamente.
# Recuperando nodos para el triángulo 615 con ids: [1128 1136 1129 1328 1329 1304]
# Triángulo 615 - Nodos: [np.int32(1129), np.int32(1137), np.int32(1130), np.int32(1329), np.int32(1330), np.int32(1305)] - Material: Steel
# Elemento 615 - Nodos: [np.int32(1129), np.int32(1137), np.int32(1130), np.int32(1329), np.int32(1330), np.int32(1305)] - Material: Steel
# Elemento 615 procesado correctamente.
# Recuperando nodos para el triángulo 616 con ids: [1129 1136 1137 1329 1330 1331]
# Triángulo 616 - Nodos: [np.int32(1130), np.int32(1137), np.int32(1138), np.int32(1330), np.int32(1331), np.int32(1332)] - Material: Steel
# Elemento 616 - Nodos: [np.int32(1130), np.int32(1137), np.int32(1138), np.int32(1330), np.int32(1331), np.int32(1332)] - Material: Steel
# Elemento 616 procesado correctamente.
# Recuperando nodos para el triángulo 617 con ids: [1129 1137 1130 1331 1332 1307]
# Triángulo 617 - Nodos: [np.int32(1130), np.int32(1138), np.int32(1131), np.int32(1332), np.int32(1333), np.int32(1308)] - Material: Steel
# Elemento 617 - Nodos: [np.int32(1130), np.int32(1138), np.int32(1131), np.int32(1332), np.int32(1333), np.int32(1308)] - Material: Steel
# Elemento 617 procesado correctamente.
# Recuperando nodos para el triángulo 618 con ids: [1130 1137 1138 1332 1333 1334]
# Triángulo 618 - Nodos: [np.int32(1131), np.int32(1138), np.int32(1139), np.int32(1333), np.int32(1334), np.int32(1335)] - Material: Steel
# Elemento 618 - Nodos: [np.int32(1131), np.int32(1138), np.int32(1139), np.int32(1333), np.int32(1334), np.int32(1335)] - Material: Steel
# Elemento 618 procesado correctamente.
# Recuperando nodos para el triángulo 619 con ids: [1130 1138 1131 1334 1335 1310]
# Triángulo 619 - Nodos: [np.int32(1131), np.int32(1139), np.int32(1132), np.int32(1335), np.int32(1336), np.int32(1311)] - Material: Steel
# Elemento 619 - Nodos: [np.int32(1131), np.int32(1139), np.int32(1132), np.int32(1335), np.int32(1336), np.int32(1311)] - Material: Steel
# Elemento 619 procesado correctamente.
# Recuperando nodos para el triángulo 620 con ids: [1131 1138 1139 1335 1336 1337]
# Triángulo 620 - Nodos: [np.int32(1132), np.int32(1139), np.int32(1140), np.int32(1336), np.int32(1337), np.int32(1338)] - Material: Steel
# Elemento 620 - Nodos: [np.int32(1132), np.int32(1139), np.int32(1140), np.int32(1336), np.int32(1337), np.int32(1338)] - Material: Steel
# Elemento 620 procesado correctamente.
# Recuperando nodos para el triángulo 621 con ids: [1131 1139 1132 1337 1338 1313]
# Triángulo 621 - Nodos: [np.int32(1132), np.int32(1140), np.int32(1133), np.int32(1338), np.int32(1339), np.int32(1314)] - Material: Steel
# Elemento 621 - Nodos: [np.int32(1132), np.int32(1140), np.int32(1133), np.int32(1338), np.int32(1339), np.int32(1314)] - Material: Steel
# Elemento 621 procesado correctamente.
# Recuperando nodos para el triángulo 622 con ids: [1132 1139 1140 1338 1339 1340]
# Triángulo 622 - Nodos: [np.int32(1133), np.int32(1140), np.int32(1141), np.int32(1339), np.int32(1340), np.int32(1341)] - Material: Steel
# Elemento 622 - Nodos: [np.int32(1133), np.int32(1140), np.int32(1141), np.int32(1339), np.int32(1340), np.int32(1341)] - Material: Steel
# Elemento 622 procesado correctamente.
# Recuperando nodos para el triángulo 623 con ids: [1132 1140 1133 1340 1341 1316]
# Triángulo 623 - Nodos: [np.int32(1133), np.int32(1141), np.int32(1134), np.int32(1341), np.int32(1342), np.int32(1317)] - Material: Steel
# Elemento 623 - Nodos: [np.int32(1133), np.int32(1141), np.int32(1134), np.int32(1341), np.int32(1342), np.int32(1317)] - Material: Steel
# Elemento 623 procesado correctamente.
# Recuperando nodos para el triángulo 624 con ids: [1133 1140 1141 1341 1342 1343]
# Triángulo 624 - Nodos: [np.int32(1134), np.int32(1141), np.int32(1142), np.int32(1342), np.int32(1343), np.int32(1344)] - Material: Steel
# Elemento 624 - Nodos: [np.int32(1134), np.int32(1141), np.int32(1142), np.int32(1342), np.int32(1343), np.int32(1344)] - Material: Steel
# Elemento 624 procesado correctamente.
# Recuperando nodos para el triángulo 625 con ids: [1133 1141 1134 1343 1344 1319]
# Triángulo 625 - Nodos: [np.int32(1134), np.int32(1142), np.int32(1135), np.int32(1344), np.int32(1345), np.int32(1320)] - Material: Steel
# Elemento 625 - Nodos: [np.int32(1134), np.int32(1142), np.int32(1135), np.int32(1344), np.int32(1345), np.int32(1320)] - Material: Steel
# Elemento 625 procesado correctamente.
# Recuperando nodos para el triángulo 626 con ids: [1134 1141 1142 1344 1345 1346]
# Triángulo 626 - Nodos: [np.int32(1135), np.int32(1142), np.int32(1143), np.int32(1345), np.int32(1346), np.int32(1347)] - Material: Steel
# Elemento 626 - Nodos: [np.int32(1135), np.int32(1142), np.int32(1143), np.int32(1345), np.int32(1346), np.int32(1347)] - Material: Steel
# Elemento 626 procesado correctamente.
# Recuperando nodos para el triángulo 627 con ids: [1134 1142 1135 1346 1347 1322]
# Triángulo 627 - Nodos: [np.int32(1135), np.int32(1143), np.int32(1136), np.int32(1347), np.int32(1348), np.int32(1323)] - Material: Steel
# Elemento 627 - Nodos: [np.int32(1135), np.int32(1143), np.int32(1136), np.int32(1347), np.int32(1348), np.int32(1323)] - Material: Steel
# Elemento 627 procesado correctamente.
# Recuperando nodos para el triángulo 628 con ids: [1135 1142 1143 1347 1348 1349]
# Triángulo 628 - Nodos: [np.int32(1136), np.int32(1143), np.int32(1144), np.int32(1348), np.int32(1349), np.int32(1350)] - Material: Steel
# Elemento 628 - Nodos: [np.int32(1136), np.int32(1143), np.int32(1144), np.int32(1348), np.int32(1349), np.int32(1350)] - Material: Steel
# Elemento 628 procesado correctamente.
# Recuperando nodos para el triángulo 629 con ids: [1135 1143  134 1349 1350 1325]
# Triángulo 629 - Nodos: [np.int32(1136), np.int32(1144), np.int32(135), np.int32(1350), np.int32(1351), np.int32(1326)] - Material: Steel
# Elemento 629 - Nodos: [np.int32(1136), np.int32(1144), np.int32(135), np.int32(1350), np.int32(1351), np.int32(1326)] - Material: Steel
# Elemento 629 procesado correctamente.
# Recuperando nodos para el triángulo 630 con ids: [ 134 1143  135 1350 1351  143]
# Triángulo 630 - Nodos: [np.int32(135), np.int32(1144), np.int32(136), np.int32(1351), np.int32(1352), np.int32(144)] - Material: Steel
# Elemento 630 - Nodos: [np.int32(135), np.int32(1144), np.int32(136), np.int32(1351), np.int32(1352), np.int32(144)] - Material: Steel
# Elemento 630 procesado correctamente.
# Recuperando nodos para el triángulo 631 con ids: [ 203    0 1136  212 1352 1327]
# Triángulo 631 - Nodos: [np.int32(204), np.int32(1), np.int32(1137), np.int32(213), np.int32(1353), np.int32(1328)] - Material: Steel
# Elemento 631 - Nodos: [np.int32(204), np.int32(1), np.int32(1137), np.int32(213), np.int32(1353), np.int32(1328)] - Material: Steel
# Elemento 631 procesado correctamente.
# Recuperando nodos para el triángulo 632 con ids: [1136    0  162 1352  170 1353]
# Triángulo 632 - Nodos: [np.int32(1137), np.int32(1), np.int32(163), np.int32(1353), np.int32(171), np.int32(1354)] - Material: Steel
# Elemento 632 - Nodos: [np.int32(1137), np.int32(1), np.int32(163), np.int32(1353), np.int32(171), np.int32(1354)] - Material: Steel
# Elemento 632 procesado correctamente.
# Recuperando nodos para el triángulo 633 con ids: [1136  162 1137 1353 1354 1330]
# Triángulo 633 - Nodos: [np.int32(1137), np.int32(163), np.int32(1138), np.int32(1354), np.int32(1355), np.int32(1331)] - Material: Steel
# Elemento 633 - Nodos: [np.int32(1137), np.int32(163), np.int32(1138), np.int32(1354), np.int32(1355), np.int32(1331)] - Material: Steel
# Elemento 633 procesado correctamente.
# Recuperando nodos para el triángulo 634 con ids: [1137  162  163 1354  171 1355]
# Triángulo 634 - Nodos: [np.int32(1138), np.int32(163), np.int32(164), np.int32(1355), np.int32(172), np.int32(1356)] - Material: Steel
# Elemento 634 - Nodos: [np.int32(1138), np.int32(163), np.int32(164), np.int32(1355), np.int32(172), np.int32(1356)] - Material: Steel
# Elemento 634 procesado correctamente.
# Recuperando nodos para el triángulo 635 con ids: [1137  163 1138 1355 1356 1333]
# Triángulo 635 - Nodos: [np.int32(1138), np.int32(164), np.int32(1139), np.int32(1356), np.int32(1357), np.int32(1334)] - Material: Steel
# Elemento 635 - Nodos: [np.int32(1138), np.int32(164), np.int32(1139), np.int32(1356), np.int32(1357), np.int32(1334)] - Material: Steel
# Elemento 635 procesado correctamente.
# Recuperando nodos para el triángulo 636 con ids: [1138  163  164 1356  172 1357]
# Triángulo 636 - Nodos: [np.int32(1139), np.int32(164), np.int32(165), np.int32(1357), np.int32(173), np.int32(1358)] - Material: Steel
# Elemento 636 - Nodos: [np.int32(1139), np.int32(164), np.int32(165), np.int32(1357), np.int32(173), np.int32(1358)] - Material: Steel
# Elemento 636 procesado correctamente.
# Recuperando nodos para el triángulo 637 con ids: [1138  164 1139 1357 1358 1336]
# Triángulo 637 - Nodos: [np.int32(1139), np.int32(165), np.int32(1140), np.int32(1358), np.int32(1359), np.int32(1337)] - Material: Steel
# Elemento 637 - Nodos: [np.int32(1139), np.int32(165), np.int32(1140), np.int32(1358), np.int32(1359), np.int32(1337)] - Material: Steel
# Elemento 637 procesado correctamente.
# Recuperando nodos para el triángulo 638 con ids: [1139  164  165 1358  173 1359]
# Triángulo 638 - Nodos: [np.int32(1140), np.int32(165), np.int32(166), np.int32(1359), np.int32(174), np.int32(1360)] - Material: Steel
# Elemento 638 - Nodos: [np.int32(1140), np.int32(165), np.int32(166), np.int32(1359), np.int32(174), np.int32(1360)] - Material: Steel
# Elemento 638 procesado correctamente.
# Recuperando nodos para el triángulo 639 con ids: [1139  165 1140 1359 1360 1339]
# Triángulo 639 - Nodos: [np.int32(1140), np.int32(166), np.int32(1141), np.int32(1360), np.int32(1361), np.int32(1340)] - Material: Steel
# Elemento 639 - Nodos: [np.int32(1140), np.int32(166), np.int32(1141), np.int32(1360), np.int32(1361), np.int32(1340)] - Material: Steel
# Elemento 639 procesado correctamente.
# Recuperando nodos para el triángulo 640 con ids: [1140  165  166 1360  174 1361]
# Triángulo 640 - Nodos: [np.int32(1141), np.int32(166), np.int32(167), np.int32(1361), np.int32(175), np.int32(1362)] - Material: Steel
# Elemento 640 - Nodos: [np.int32(1141), np.int32(166), np.int32(167), np.int32(1361), np.int32(175), np.int32(1362)] - Material: Steel
# Elemento 640 procesado correctamente.
# Recuperando nodos para el triángulo 641 con ids: [1140  166 1141 1361 1362 1342]
# Triángulo 641 - Nodos: [np.int32(1141), np.int32(167), np.int32(1142), np.int32(1362), np.int32(1363), np.int32(1343)] - Material: Steel
# Elemento 641 - Nodos: [np.int32(1141), np.int32(167), np.int32(1142), np.int32(1362), np.int32(1363), np.int32(1343)] - Material: Steel
# Elemento 641 procesado correctamente.
# Recuperando nodos para el triángulo 642 con ids: [1141  166  167 1362  175 1363]
# Triángulo 642 - Nodos: [np.int32(1142), np.int32(167), np.int32(168), np.int32(1363), np.int32(176), np.int32(1364)] - Material: Steel
# Elemento 642 - Nodos: [np.int32(1142), np.int32(167), np.int32(168), np.int32(1363), np.int32(176), np.int32(1364)] - Material: Steel
# Elemento 642 procesado correctamente.
# Recuperando nodos para el triángulo 643 con ids: [1141  167 1142 1363 1364 1345]
# Triángulo 643 - Nodos: [np.int32(1142), np.int32(168), np.int32(1143), np.int32(1364), np.int32(1365), np.int32(1346)] - Material: Steel
# Elemento 643 - Nodos: [np.int32(1142), np.int32(168), np.int32(1143), np.int32(1364), np.int32(1365), np.int32(1346)] - Material: Steel
# Elemento 643 procesado correctamente.
# Recuperando nodos para el triángulo 644 con ids: [1142  167  168 1364  176 1365]
# Triángulo 644 - Nodos: [np.int32(1143), np.int32(168), np.int32(169), np.int32(1365), np.int32(177), np.int32(1366)] - Material: Steel
# Elemento 644 - Nodos: [np.int32(1143), np.int32(168), np.int32(169), np.int32(1365), np.int32(177), np.int32(1366)] - Material: Steel
# Elemento 644 procesado correctamente.
# Recuperando nodos para el triángulo 645 con ids: [1142  168 1143 1365 1366 1348]
# Triángulo 645 - Nodos: [np.int32(1143), np.int32(169), np.int32(1144), np.int32(1366), np.int32(1367), np.int32(1349)] - Material: Steel
# Elemento 645 - Nodos: [np.int32(1143), np.int32(169), np.int32(1144), np.int32(1366), np.int32(1367), np.int32(1349)] - Material: Steel
# Elemento 645 procesado correctamente.
# Recuperando nodos para el triángulo 646 con ids: [1143  168  169 1366  177 1367]
# Triángulo 646 - Nodos: [np.int32(1144), np.int32(169), np.int32(170), np.int32(1367), np.int32(178), np.int32(1368)] - Material: Steel
# Elemento 646 - Nodos: [np.int32(1144), np.int32(169), np.int32(170), np.int32(1367), np.int32(178), np.int32(1368)] - Material: Steel
# Elemento 646 procesado correctamente.
# Recuperando nodos para el triángulo 647 con ids: [1143  169  135 1367 1368 1351]
# Triángulo 647 - Nodos: [np.int32(1144), np.int32(170), np.int32(136), np.int32(1368), np.int32(1369), np.int32(1352)] - Material: Steel
# Elemento 647 - Nodos: [np.int32(1144), np.int32(170), np.int32(136), np.int32(1368), np.int32(1369), np.int32(1352)] - Material: Steel
# Elemento 647 procesado correctamente.
# Recuperando nodos para el triángulo 648 con ids: [ 135  169    8 1368  178  144]
# Triángulo 648 - Nodos: [np.int32(136), np.int32(170), np.int32(9), np.int32(1369), np.int32(179), np.int32(145)] - Material: Steel
# Elemento 648 - Nodos: [np.int32(136), np.int32(170), np.int32(9), np.int32(1369), np.int32(179), np.int32(145)] - Material: Steel
# Elemento 648 procesado correctamente.

# %%
node_index_map = {node.name: i for i, node in enumerate(nodes)}
# Datos para el gráfico
# Datos para el gráfico
x = np.array([node.coordenadas[0] for node in nodes])  # Coordenadas X
y = np.array([node.coordenadas[1] for node in nodes])  # Coordenadas Y

# Gráfico
fig, ax = plt.subplots(figsize=(8, 6))

# Dibujar los elementos LST (líneas entre los nodos de cada elemento)
for elem in elements:
    coords = np.array([[node.coordenadas[0], node.coordenadas[1]] for node in elem.nodes])
    coords = np.vstack([coords, coords[0]])  # Cerrar el triángulo
    ax.plot(coords[:, 0], coords[:, 1], 'k-', linewidth=1)  # Dibujar el triángulo en negro

# Dibujar nodos del grupo "Force" (en rojo)
for i, node in enumerate(grupos["BC_1"]):
    idx = node_index_map[node.name]
    ax.plot(x[idx], y[idx], 'ro', markersize=6, label="Carga (Force)" if i == 0 else "")

# Dibujar nodos del grupo "Nut" (en azul)
for i, node in enumerate(grupos["BC_R1"]):
    idx = node_index_map[node.name]
    ax.plot(x[idx], y[idx], 'bo', markersize=6, label="Apoyo" if i == 0 else "")

# Gráfico final
ax.set_title("Structure with Nodes Force and Restrain")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_aspect("equal")

# Leyenda
ax.legend(
    handles=[
        plt.Line2D([0], [0], color='k', lw=1, label='Element'),
        plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='r', markersize=6, label='Force'),
        plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='b', markersize=6, label='Nut')
    ],
    loc="center left",
    bbox_to_anchor=(1.0, 0.5)  # Poner la leyenda fuera del gráfico
)

plt.tight_layout(rect=[0, 0, 0.85, 1])  # Ajustar el diseño
plt.show()

# %%
def solve(nodes, elements):
    """
    Resuelve el sistema FEM considerando cargas distribuidas en líneas.
    
    Args:
        nodes (list): Lista de nodos con .idx, .nodalLoad, .restrain
        elements (list): Lista de elementos con .kg, .idx

    Returns:
        u (np.ndarray): Desplazamientos globales
        F_reactions (np.ndarray): Reacciones en DOFs restringidos
        Fj (np.ndarray): Fuerzas nodales aplicadas
        F_total (np.ndarray): Fuerzas totales incluyendo reacciones
    """
    
    nNodes = len(nodes)
    system_nDof = 2 * nNodes  # 2 DOFs por nodo
    
    # === CARGAS DISTRIBUIDAS EN LÍNEAS ===
    F_line_global = np.zeros(system_nDof)
    Fj = np.zeros(system_nDof)
    
    # Asignación de cargas nodales a las fuerzas aplicadas
    for node in nodes:
        for dof_idx, force in zip(node.idx, node.nodalLoad):
            if dof_idx >= system_nDof:
                print(f"Error: índice {dof_idx} fuera de rango para el nodo {node.name}")
                continue
            Fj[dof_idx] = force

    # === MATRIZ DE RIGIDEZ GLOBAL ===
    Kg = np.zeros((system_nDof, system_nDof))
    
    # Ensamblaje de la matriz de rigidez global
    for element in elements:
        try:
            Kg = matrix_replace(Kg, element.kg, element.idx, element.idx)
        except IndexError as e:
            print(f"Error al reemplazar en la matriz de rigidez global para el elemento {element.element_tag}.")
            print(f"Índices de DOF: {element.idx}")
            print(f"Error: {e}")
            continue  # Si ocurre un error, saltar al siguiente elemento
    
    # === RESTRICCIONES ===
    nodeIndex = np.full(system_nDof, '', dtype=str)
    for node in nodes:
        for dof_idx, status in zip(node.idx, node.restrain):
            nodeIndex[dof_idx] = status
    
    freeIndices = np.where(nodeIndex == 'f')[0]  # Índices de grados de libertad libres
    restrainedIndices = np.where(nodeIndex == 'r')[0]  # Índices de grados de libertad restringidos
    
    # === PARTICIÓN DEL SISTEMA ===
    Kff = matrix_extract(Kg, freeIndices, freeIndices)
    Kfr = matrix_extract(Kg, freeIndices, restrainedIndices)
    Krf = matrix_extract(Kg, restrainedIndices, freeIndices)
    Krr = matrix_extract(Kg, restrainedIndices, restrainedIndices)

    # === FUERZA TOTAL (aplicada + distribuida) ===
    F = Fj + F_line_global
    Ff = F[freeIndices]
    Fr = F[restrainedIndices]

    # === SOLUCIÓN ===
    # Resolución del sistema para desplazamientos libres
    uf = np.linalg.solve(Kff, Ff - Kfr @ Fr)
    
    ur = np.zeros(len(restrainedIndices))  # Desplazamientos restringidos son cero
    u = np.zeros(system_nDof)  # Desplazamientos globales
    u[freeIndices] = uf
    u[restrainedIndices] = ur

    # === REACCIONES ===
    Fr = Krf @ uf + Krr @ ur
    F_reactions = np.zeros(system_nDof)  # Fuerzas de reacción
    F_reactions[restrainedIndices] = Fr

    return u, F_reactions, Fj, F

# %% [markdown]
# De aquí para abajo empieza la configuración de las fuerzas:
#
# 1er caso: Fuerza distribuida
#
# 2do caso: Fuerza puntual
#
# 3er caso: Fuerza distribuida con peso propio

# %% [markdown]
# Primer Caso: Fuerza distribuida

# %%
def apply_distributed_force(grupo_nodos, fuerza_total_y):
    """
    Aplica una fuerza distribuida vertical (por ejemplo, peso) sobre una línea formada por nodos no alineados.
    La fuerza se reparte proporcionalmente a la longitud de los tramos y se descompone en x e y.
    """

    # Paso 1: ordena nodos si es necesario (aquí asumimos que ya están ordenados)
    nodos = grupo_nodos
    n = len(nodos)
    if n < 2:
        print("Se requieren al menos dos nodos para aplicar fuerza distribuida.")
        return

    # Paso 2: calcular longitud total de la línea
    longitudes = []
    total_length = 0
    for i in range(n - 1):
        dx = nodos[i+1].coordenadas[0] - nodos[i].coordenadas[0]
        dy = nodos[i+1].coordenadas[1] - nodos[i].coordenadas[1]  # CORRECCIÓN: dy debe ser la diferencia en 'y'
        L = np.sqrt(dx**2 + dy**2)
        longitudes.append(L)
        total_length += L

    # Paso 3: calcular carga distribuida por unidad de longitud
    q_total = fuerza_total_y  # Fuerza total a repartir
    q_lineal = q_total / total_length  # N/m

    # Paso 4: aplicar cargas parciales a cada nodo (2 nodos por segmento)
    nodal_forces = {node.name: np.array([0.0, 0.0]) for node in nodos}

    for i in range(n - 1):
        ni = nodos[i]
        nj = nodos[i + 1]
        xi, yi = ni.coordenadas[0], ni.coordenadas[1]
        xj, yj = nj.coordenadas[0], nj.coordenadas[1]

        dx = xj - xi
        dy = yj - yi
        L = longitudes[i]

        # Dirección normalizada del tramo (unitario)
        vx = dx / L
        vy = dy / L

        # Vector perpendicular (hacia abajo)
        nx = vy
        ny = -vx

        # Fuerza total sobre el tramo
        Fi = q_lineal * L  # Total fuerza sobre el tramo

        # Componente de fuerza en x y y (globales)
        fx = Fi * nx
        fy = Fi * ny

        # Distribuir mitad a cada nodo
        nodal_forces[ni.name] += np.array([fx / 2, fy / 2])
        nodal_forces[nj.name] += np.array([fx / 2, fy / 2])

    # Paso 5: Asignar las fuerzas nodales
    for node in nodos:
        fx, fy = nodal_forces[node.name]
        # Asegurarse de que los índices son correctos
        dof_x, dof_y = node.idx
        node.set_nodalLoad([fx, fy])  # Aplicar la carga a cada nodo

    print(f"Fuerza distribuida aplicada correctamente sobre {n} nodos.")

# %% [markdown]
# Acá se define el segundo caso: Fuerza puntual

# %%
def single_force(nodes, grupo_nodos, fuerza_total_y):
    """
    Aplica una fuerza puntual vertical (por ejemplo, peso) sobre un nodo específico.
    La fuerza se descompone en x e y.
    """
    for j in nodes:
        j.set_nodalLoad([0,0])
    # Paso 1: ordena nodos si es necesario (aquí asumimos que ya están ordenados)
    nodos = grupo_nodos


    # Paso 2: escoger un nodo específico (por ejemplo, el primero)
    nodo = nodos[0]  # Cambia esto si deseas otro nodo
    x, y = nodo.coordenadas[0], nodo.coordenadas[1]
    # Paso 3: aplicar carga puntual
    # Fuerza total a aplicar
    F_total = fuerza_total_y  # N
    # Componente de fuerza en x y y (globales)
    fx = 0.0  # Cambia esto si deseas una fuerza en x
    fy = F_total  # Fuerza en y
    nodo.set_nodalLoad([0,-fy])

# %%
def apply_distributed_force_especial(grupos, elementos, fuerza_total_y):
    # Paso 1: Aplicar fuerzas distribuidas en los elementos
    for element in elementos:
        centroid = element.get_centroid()
        area = element.area
        thickness = element.section.thickness
        rho = element.section.material.rho
        weight = area * thickness * rho/1000

        # Fuerzas internas (peso distribuido)
        F_interna = element.body_weight_forces(x=centroid[0], y=centroid[1], force_vector=[0, weight]) / 3

        # Asignar fuerzas a los nodos del elemento
        for node in element.node_list:
            # Asignar o sumar la carga al nodo
            if np.all(node.nodalLoad == 0):
                node.set_nodalLoad([F_interna[0], -F_interna[1]])
            else:
                node.set_nodalLoad([node.nodalLoad[0] + F_interna[0], node.nodalLoad[1] - F_interna[1]])

    # Paso 2: Aplicar la carga distribuida a lo largo de los nodos en el grupo "BC_1"
    if "BC_1" not in grupos:
        print("Advertencia: 'BC_1' no se encuentra en grupos.")
        return

    nodos_fuerza = grupos["BC_1"]
    n = len(nodos_fuerza)

    if n < 2:
        print("Se requieren al menos dos nodos para aplicar fuerza distribuida.")
        return

    # Paso 3: Calcular longitud total de la línea
    total_length = sum(np.linalg.norm(np.array(nodos_fuerza[i+1].coordenadas) - np.array(nodos_fuerza[i].coordenadas)) for i in range(n - 1))
    
    # Paso 4: Calcular la carga distribuida por unidad de longitud
    q_lineal = fuerza_total_y / total_length  # N/m

    # Paso 5: Distribuir la carga a los nodos
    nodal_forces = {node.name: np.array([0.0, 0.0]) for node in nodos_fuerza}

    for i in range(n - 1):
        ni = nodos_fuerza[i]
        nj = nodos_fuerza[i + 1]
        xi, yi = ni.coordenadas
        xj, yj = nj.coordenadas

        dx = xj - xi
        dy = yj - yi
        L = np.sqrt(dx**2 + dy**2)

        # Dirección normalizada del tramo
        vx, vy = dx / L, dy / L
        # Vector perpendicular (hacia abajo)
        nx, ny = vy, -vx

        # Fuerza total sobre el tramo
        Fi = q_lineal * L

        # Componente de fuerza en x y y (globales)
        fx, fy = Fi * nx, Fi * ny

        # Distribuir la mitad a cada nodo
        nodal_forces[ni.name] += np.array([fx / 2, fy / 2])
        nodal_forces[nj.name] += np.array([fx / 2, fy / 2])

    # Paso 6: Asignar fuerzas nodales a los nodos
    for node in nodos_fuerza:
        fx, fy = nodal_forces[node.name]
        f_px, f_py = node.nodalLoad
        node.set_nodalLoad([fx + f_px, fy + f_py])

    print("Fuerza distribuida aplicada correctamente sobre los nodos.")

# %%
def ensure_dir(folder):
    if not os.path.exists(folder):
        os.makedirs(folder)
def compute_stress_strain_components(elements, u):
    results = []

    for elem in elements:
        # Obtener tensiones y deformaciones
        sigma, epsilon, _ = elem.get_element_stress(u)  # σxx, σyy, σxy
        exx, eyy, exy = epsilon
        sxx, syy, sxy = sigma

        # Deformaciones principales
        avg_eps = 0.5 * (exx + eyy)
        rad_eps = np.sqrt(((exx - eyy) / 2) ** 2 + exy ** 2)
        eps1 = avg_eps + rad_eps
        eps2 = avg_eps - rad_eps

        # Tensiones principales
        avg_sig = 0.5 * (sxx + syy)
        rad_sig = np.sqrt(((sxx - syy) / 2) ** 2 + sxy ** 2)
        sig1 = avg_sig + rad_sig
        sig2 = avg_sig - rad_sig

        results.append({
            "element": elem.element_tag,
            "σxx": sxx, "σyy": syy, "σxy": sxy,
            "εxx": exx, "εyy": eyy, "εxy": exy,
            "σ1": sig1, "σ2": sig2,
            "ε1": eps1, "ε2": eps2
        })

    return results
def average_element_values_to_nodes(nodes, elements, element_values):
    """
    Convierte valores definidos por elemento (por ejemplo σ1) en valores nodales por promedio.
    """
    from collections import defaultdict

    # Suma de valores y conteo
    val_sum = defaultdict(float)
    val_count = defaultdict(int)

    for elem, val in zip(elements, element_values):
        for node in elem.node_list:
            val_sum[node.name] += val
            val_count[node.name] += 1

    # Asignar promedio a cada nodo
    node_id_to_avg = {
        nid: val_sum[nid] / val_count[nid] for nid in val_sum
    }

    # Generar array en orden de nodos
    node_id_to_index = {node.name: i for i, node in enumerate(nodes)}
    nodal_values = np.array([
        node_id_to_avg[node.name] for node in nodes
    ])

    return nodal_values
import matplotlib.tri as mtri
def plot_scalar_field_on_mesh(nodes, elements, values, title, folder="figuras", filename=None, cmap="viridis"):
    """
    Visualiza un campo escalar definido por nodo sobre elementos Quad4 (no triangulado),
    sin mostrar líneas entre elementos. Cada quad se colorea interpolando sus valores nodales.
    """

    from matplotlib.collections import PolyCollection

    ensure_dir(folder)

    # Coordenadas y valores
    node_id_to_index = {node.name: i for i, node in enumerate(nodes)}
    xs = np.array([node.coordenadas[0] for node in nodes])
    ys = np.array([node.coordenadas[1] for node in nodes])

    # Usamos 'values' directamente, ya que es el valor nodal
    values_nodal = np.array(values)  # Asignamos la variable 'values' a 'values_nodal'

    # Polígonos y colores
    polygons = []
    face_colors = []

    for elem in elements:
        # Obtener índices de los nodos del quad
        ids = [node_id_to_index[n.name] for n in elem.node_list]

        # Obtener coordenadas del quad (cerrado)
        poly_coords = [(xs[i], ys[i]) for i in ids]
        polygons.append(poly_coords)

        # Color: promedio de los valores nodales del elemento
        avg_value = np.mean([values_nodal[i] for i in ids])
        face_colors.append(avg_value)

    # Normalizar colores
    norm = plt.Normalize(vmin=min(values_nodal), vmax=max(values_nodal))
    cmap_obj = plt.get_cmap(cmap)
    face_colors_mapped = [cmap_obj(norm(val)) for val in face_colors]

    # Crear colección de polígonos
    collection = PolyCollection(polygons, facecolors=face_colors_mapped, edgecolors='none')

    # Graficar
    fig, ax = plt.subplots(figsize=(8, 6))
    ax.add_collection(collection)
    ax.autoscale()
    ax.set_aspect('equal')
    ax.set_title(title)
    ax.set_xlabel("x")
    ax.set_ylabel("y")

    # Barra de color
    sm = plt.cm.ScalarMappable(cmap=cmap_obj, norm=norm)
    sm.set_array([])
    cbar = fig.colorbar(sm, ax=ax, shrink=0.9, pad=0.04)
    cbar.set_label(title)

    plt.tight_layout()

    # Guardar imagen
    if filename is None:
        filename = title.replace(" ", "_").replace("—", "-") + ".png"
    filepath = os.path.join(folder, filename)
    plt.savefig(filepath, dpi=300)
    plt.close(fig)

def plot_all_fields(results, nodes, elements, i):
    fields = ["σxx", "σyy", "σxy", "σ1", "σ2", "εxx", "εyy", "εxy", "ε1", "ε2"]
    titles = {
        "σxx": "Stress σxx", "σyy": "Stress σyy", "σxy": "Stress σxy",
        "σ1": "Maximum Principal Stress σ1", "σ2": "Minimum Principal Stress σ2",
        "εxx": "Strain εxx", "εyy": "Strain εyy", "εxy": "Strain εxy",
        "ε1": "Maximum Principal Strain ε1", "ε2": "Minimum Principal Strain ε2"
    }

    caso = f"Case low resolution {i+1}"

    for field in fields:
        element_values = [res[field] for res in results]
        nodal_values = average_element_values_to_nodes(nodes, elements, element_values)
        plot_scalar_field_on_mesh(nodes, elements, nodal_values, f"{caso} — {titles[field]}", folder="Resultados")

# %%
def plot_deformed_shape(nodes, elements, u, contador, scale, folder="figuras"):
    """
    Dibuja la estructura deformada y original, marcando nodos cargados y restringidos.

    Args:
        nodes (list): lista de nodos con .coordenadas, .name, .idx
        elements (list): lista de elementos con .node_list
        u (np.ndarray): vector de desplazamientos global
        contador (int): índice del caso (0, 1, 2)
        scale (float): factor de amplificación de la deformación
    """
    filename = None
    # Inicializar vectores de coordenadas
    n = len(nodes)
    x = np.zeros(n)
    y = np.zeros(n)
    x_def = np.zeros(n)
    y_def = np.zeros(n)

    # Construcción coordenadas originales y deformadas usando node.idx
    for i, node in enumerate(nodes):
        x[i] = node.coordenadas[0]
        y[i] = node.coordenadas[1]
        x_def[i] = x[i] + scale * u[node.idx[0]]
        y_def[i] = y[i] + scale * u[node.idx[1]]

    # Mapeo name → índice en array
    node_index_map = {node.name: i for i, node in enumerate(nodes)}


    # Gráfico
    fig, ax = plt.subplots(figsize=(8, 6))

    # Estructura original (negro)
    for elem in elements:
        indices = [node_index_map[node.name] for node in elem.node_list]
        coords = np.array([[x[i], y[i]] for i in indices + [indices[0]]])
        ax.plot(coords[:, 0], coords[:, 1], 'k-', linewidth=1)

    # Estructura deformada (rojo punteado)
    for elem in elements:
        indices = [node_index_map[node.name] for node in elem.node_list]
        coords = np.array([[x_def[i], y_def[i]] for i in indices + [indices[0]]])
        ax.plot(coords[:, 0], coords[:, 1], 'r--', linewidth=1)



    # Título dinámico por caso
    if contador == 0:
        title="Deformed sctructure - Case 1 low resolution"
        ax.set_title(title)
    elif contador == 1:
        title="Deformed sctructure - Case 2 low resolution"
        ax.set_title(title)
    elif contador == 2:
        title="Deformed sctructure - Case 3 low resolution"
        ax.set_title(title)

    ax.set_xlabel("x")
    ax.set_ylabel("y")
    ax.set_aspect("equal")

    # Leyenda fuera del gráfico
    ax.legend(
        handles=[
            plt.Line2D([0], [0], color='k', lw=1, label='Elemento'),
            plt.Line2D([0], [0], linestyle='--', color='r', lw=1, label='Deformada')
        ],
        loc="center left",
        bbox_to_anchor=(1.02, 0.5)
    )

    plt.tight_layout(rect=[0, 0, 0.85, 1])
    ensure_dir(folder)
    if filename is None:
        filename = title.replace(" ", "_").replace("—", "-") + ".png"
    filepath = os.path.join(folder, filename)
    plt.savefig(filepath, dpi=300)

# %%
if "BC_1" in grupos:
    nodos_fuerza = grupos["BC_1"]
for i in range(3):
    if i == 0:
        apply_distributed_force(nodos_fuerza, fuerza_total_y=2000000*kgf)
        u=solve(nodes, elements)
        plot_deformed_shape(nodes, elements, u, i, scale=1.5, folder="Resultados")
        results = compute_stress_strain_components(elements, u)
        plot_all_fields(results, nodes, elements, i)
        for j in nodes:
            j.set_nodalLoad([0,0])
    elif i == 1:
        single_force(nodes, nodos_fuerza, fuerza_total_y=30*kgf)
        u=solve(nodes, elements)
        plot_deformed_shape(nodes, elements, u, i, scale=0.5, folder="Resultados")
        results = compute_stress_strain_components(elements, u)
        plot_all_fields(results, nodes, elements, i)
        for j in nodes:
            j.set_nodalLoad([0,0])
    elif i == 2:
        apply_distributed_force_especial(grupos, elements, fuerza_total_y=30*kgf)
        u=solve(nodes, elements)
        plot_deformed_shape(nodes, elements, u, i, scale=1, folder="Resultados")
        results = compute_stress_strain_components(elements, u)
        plot_all_fields(results, nodes, elements, i)
        results_inicial= results
        for j in nodes:
            j.set_nodalLoad([0,0])
results=0
# Out:
# Fuerza distribuida aplicada correctamente sobre 37 nodos.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 6
#       4 if i == 0:
#       5     apply_distributed_force(nodos_fuerza, fuerza_total_y=2000000*kgf)
# ----> 6     u=solve(nodes, elements)
#       7     plot_deformed_shape(nodes, elements, u, i, scale=1.5, folder="Resultados")
#       8     results = compute_stress_strain_components(elements, u)
#
# Cell In[7], line 37, in solve(nodes, elements)
#      35 for element in elements:
#      36     try:
# ---> 37         Kg = matrix_replace(Kg, element.kg, element.idx, element.idx)
#      38     except IndexError as e:
#      39         print(f"Error al reemplazar en la matriz de rigidez global para el elemento {element.element_tag}.")
#
# File c:\Users\HP\Desktop\Uandes\9no_semestre\01-Finite-Element\Prueba_2\LST\functions.py:36, in matrix_replace(matrix, matrix_add, row_indices, col_indices)
#      33 updated_matrix = matrix.copy()
#      35 # Use np.ix_ for better readability and performance
# ---> 36 updated_matrix[np.ix_(row_indices, col_indices)] += matrix_add
#      38 return updated_matrix
#
# ValueError: operands could not be broadcast together with shapes (12,12) (6,6) (12,12)

# %% [markdown]
# Ahora con los 3 casos listos, procedemos a ver el tema de la optimización de sección mantiniendo el volumen constante

# %%
def total_volume(elements):
    return sum(elem.area * elem.section.thickness for elem in elements)
V0 = total_volume(elements)

# %%
def total_volume_of_group(elements, group_nodes):
    total_volume = 0.0
    area_total = 0.0
    group_node_ids = set(node.name for node in group_nodes)

    for elem in elements:
        elem_node_ids = set(node.name for node in elem.node_list)
        if elem_node_ids.issubset(group_node_ids):  # ✅ Solo si todos los nodos están en el grupo
            total_volume += elem.area * elem.section.thickness
            area_total += elem.area

    return total_volume, area_total

# --- Volúmenes y áreas ---
# Paso 1: calcular volumen inicial
V_total_inicial = total_volume(elements)

# Paso 2: definir grupos
heads_nodes = grupos['Heads']
handle_nodes = grupos['Handle_big'] + grupos['Handle_thin']

# Paso 3: calcular volumen y área de cada grupo
V_heads, A_heads = total_volume_of_group(elements, heads_nodes)
V_handle, A_handle = total_volume_of_group(elements, handle_nodes)

# Paso 4: definir porcentaje de redistribución
reduction_factor = 1.5  # 5% de reducción en manilla

# Paso 5: calcular nuevos espesores
new_thickness_handle = (V_handle * reduction_factor) / A_handle
V_handle_nuevo = new_thickness_handle * A_handle
V_heads_nuevo = V_total_inicial - V_handle_nuevo
new_thickness_heads = V_heads_nuevo / A_heads

# Paso 6: aplicar nuevos espesores
# Primero a manilla
handle_node_ids = set(node.name for node in handle_nodes)
for elem in elements:
    elem_node_ids = set(node.name for node in elem.node_list)
    if elem_node_ids.issubset(handle_node_ids):
        elem.section.thickness = new_thickness_handle

# Luego a heads
heads_node_ids = set(node.name for node in heads_nodes)
for elem in elements:
    elem_node_ids = set(node.name for node in elem.node_list)
    if elem_node_ids.issubset(heads_node_ids):
        elem.section.thickness = new_thickness_heads

# Paso 7: chequear volumen
V_total_final = total_volume(elements)
print("Volumen inicial:", V_total_inicial)
print("Volumen final:", V_total_final)
print("Diferencia relativa:", abs(V_total_final - V_total_inicial) / V_total_inicial)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[421], line 19
#      16 V_total_inicial = total_volume(elements)
#      18 # Paso 2: definir grupos
# ---> 19 heads_nodes = grupos['Heads']
#      20 handle_nodes = grupos['Handle_big'] + grupos['Handle_thin']
#      22 # Paso 3: calcular volumen y área de cada grupo
#
# KeyError: 'Heads'

# %%
print("Volumen total inicial:", V0)
print("Veo que los elementos de la manilla tengan el nuevo espesor:", elements[44].section.thickness)
print("Volumen total después de la unificación:", total_volume(elements))

apply_distributed_force_especial(grupos, elements, fuerza_total_y=30*kgf)
u=solve(nodes, elements)
#plot_deformed_shape(nodes, elements, u, i, scale=5, folder="Resultados")
results = compute_stress_strain_components(elements, u)
#plot_all_fields(results, nodes, elements, i)
print(results_inicial)
print(results)
# Out:
# Volumen total inicial: 6856.603566981417
# Veo que los elementos de la manilla tengan el nuevo espesor: 3.6451666287436018
# Volumen total después de la unificación: 6856.603566981413
# [{'element': 1, 'σxx': np.float64(0.38186094625188216), 'σyy': np.float64(0.04985423641777422), 'σxy': np.float64(-0.21146493864833613), 'εxx': np.float64(0.00012063975056159082), 'εyy': np.float64(-3.429671402765955e-05), 'εxy': np.float64(-0.0001973672760717804), 'σ1': np.float64(0.48469682604818237), 'σ2': np.float64(-0.05298164337852601), 'ε1': np.float64(0.00025519785785440554), 'ε2': np.float64(-0.00016885482132047427)}, {'element': 2, 'σxx': np.float64(-0.009498366952875474), 'σyy': np.float64(0.003492205489488302), 'σxy': np.float64(0.002239958992247826), 'εxx': np.float64(-3.631749716223598e-06), 'εyy': np.float64(2.4305174235461635e-06), 'εxy': np.float64(2.0906283927646374e-06), 'σ1': np.float64(0.0038675931349680523), 'σ2': np.float64(-0.009873754598355225), 'ε1': np.float64(3.0815704044917417e-06), 'ε2':
yy': np.float64(-0.29875611450402845), 'σxy': np.float64(-0.030198512770894324), 'εxx': np.float64(0.0001972709199519196), 'εyy': np.float64(-0.00016256008004189582), 'εxy': np.float64(-2.818527858616804e-05), 'σ1': np.float64(0.47349121832510543), 'σ2': np.float64(-0.2999370187749866), 'ε1': np.float64(0.00019946526885977926), 'ε2': np.float64(-0.0001647544289497555)}, {'element': 8, 'σxx': np.float64(0.009262020628984593), 'σyy': np.float64(-0.0003521292898140642), 'σxy': np.float64(0.00290098947292832), 'εxx': np.float64(3.1342907816367394e-06), 'εyy': np.float64(-1.3523125138026337e-06), 'εxy': np.float64(2.707590174733099e-06), 'σ1': np.float64(0.01006954357035474), 'σ2': np.float64(-0.0011596522311842104), 'ε1': np.float64(4.407158475256157e-06), 'ε2': np.float64(-2.6251802074220517e-06)}, {'element': 9, 'σxx': np.float64(-0.001867755939315747), 'σyy': np.float64(0.0018525309921793975), 'σxy': np.float64(-0.0012711658868371143), 'εxx': np.float64(-8.695894453958353e-07), 'εyy': np.float64(8.665444559685653e-07), 'εxy': np.float64(-1.1864214943813067e-06), 'σ1': np.float64(0.0022453847357114497), 'σ2': np.float64(-0.0022606096828477994), 'ε1': np.float64(1.468557840913186e-06), 'ε2': np.float64(-1.471602830340456e-06)}, {'element': 10, 'σxx': np.float64(-0.04553672949412118), 'σyy': np.float64(-0.5832029025710912), 'σxy':  ...

# %%
sigma1_inicial = np.array([res['σ1'] for res in results_inicial])
sigma1_actual = np.array([res['σ1'] for res in results])
# Diferencia absoluta
max_sigma1_inicial = np.max(sigma1_inicial)
max_sigma1_actual = np.max(sigma1_actual)

# Comparación
print(f"Máximo σ1 inicial: {max_sigma1_inicial:.6f}")
print(f"Máximo σ1 actual:  {max_sigma1_actual:.6f}")

if max_sigma1_actual > max_sigma1_inicial:
    print("🔺 El máximo σ1 AUMENTÓ")
elif max_sigma1_actual < max_sigma1_inicial:
    print("🔻 El máximo σ1 DISMINUYÓ")
else:
    print("⚪ El máximo σ1 NO CAMBIÓ")
# Out:
# Máximo σ1 inicial: 22.839389
# Máximo σ1 actual:  22.791645
# 🔻 El máximo σ1 DISMINUYÓ

# %%
for elem in elements:
    print(f"Elemento {elem.element_tag} - Espesor: {elem.section.thickness} mm")
# Out:
# Elemento 1 - Espesor: 3.6451666287436018 mm
# Elemento 2 - Espesor: 3.6451666287436018 mm
# Elemento 3 - Espesor: 3.6451666287436018 mm
# Elemento 4 - Espesor: 3.6451666287436018 mm
# Elemento 5 - Espesor: 3.6451666287436018 mm
# Elemento 6 - Espesor: 3.6451666287436018 mm
# Elemento 7 - Espesor: 3.6451666287436018 mm
# Elemento 8 - Espesor: 3.6451666287436018 mm
# Elemento 9 - Espesor: 3.6451666287436018 mm
# Elemento 10 - Espesor: 3.6451666287436018 mm
# Elemento 11 - Espesor: 3.6451666287436018 mm
# Elemento 12 - Espesor: 3.6451666287436018 mm
# Elemento 13 - Espesor: 3.6451666287436018 mm
# Elemento 14 - Espesor: 3.6451666287436018 mm
